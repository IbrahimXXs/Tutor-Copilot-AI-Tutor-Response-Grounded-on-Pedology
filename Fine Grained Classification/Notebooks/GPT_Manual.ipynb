# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added
new_entries = [
    {
        "History": "||| teacher: Let's break down the problem together. ||| student: I'm not sure I understand. ||| teacher: Can you tell me what part confuses you?",
        "Expert_Human_Tutor": "Let's go step by step. Start by thinking about what you already know, and we'll build from there.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Take a look at the shapes in the image. ||| student: They all look similar. ||| teacher: What's the main similarity you notice?",
        "Expert_Human_Tutor": "Exactly, they have similar angles. Now, let's discuss why that matters in geometry.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Let's consider the rule for adding decimals. ||| student: I get mixed up with the steps. ||| teacher: Let's review the place values together.",
        "Expert_Human_Tutor": "When we add decimals, we align by the decimal point. Each place value represents a different power of 10.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What happens when you multiply two numbers? ||| student: You get a bigger number? ||| teacher: Yes, usually, but let's think about fractions.",
        "Expert_Human_Tutor": "When multiplying fractions, you multiply the numerators and the denominators separately, which can make the result smaller.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Here’s an equation to solve. ||| student: I’m not sure about the first step. ||| teacher: What would you do with the numbers first?",
        "Expert_Human_Tutor": "Great start! You want to isolate the variable by reversing the operations step by step.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Imagine you have a big rectangle. ||| student: Yes, I can picture it. ||| teacher: What if you divide it into smaller squares?",
        "Expert_Human_Tutor": "That’s right! Each square represents a part of the whole. This is the idea behind fractions.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What do you know about triangles? ||| student: They have three sides. ||| teacher: And what else?",
        "Expert_Human_Tutor": "Exactly. They also have three angles that add up to 180 degrees.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Look at this fraction. ||| student: It’s a half. ||| teacher: Can you convert it to a decimal?",
        "Expert_Human_Tutor": "Yes, a half is 0.5 in decimal form. This is because it represents one out of two equal parts.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Let’s talk about the number line. ||| student: I know it shows numbers in order. ||| teacher: Exactly. How do you think it helps with addition?",
        "Expert_Human_Tutor": "Using a number line shows you visually how numbers increase or decrease with addition and subtraction.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: If you have two apples and get two more, what do you have? ||| student: Four apples? ||| teacher: Exactly, let’s look at how addition works.",
        "Expert_Human_Tutor": "When you add, you're combining amounts. This concept is fundamental to understanding basic arithmetic.",
        "Peda_Strategies": "explain_concept"
    }
]

# Convert new entries into a DataFrame
new_df = pd.DataFrame(new_entries)

# Append new entries to the existing dataset
df = pd.concat([df, new_df], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New entries added successfully!")
# Out:
# New entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added
new_entries_2 = [
    {
        "History": "||| teacher: Let’s solve for x in this equation. ||| student: I’m confused by the steps. ||| teacher: Which step do you find confusing?",
        "Expert_Human_Tutor": "Let's start by isolating x. We’ll reverse each operation step-by-step to simplify.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Look at this pattern in the numbers. ||| student: It seems random. ||| teacher: Try observing how each number changes.",
        "Expert_Human_Tutor": "Notice the pattern? Each step either adds or multiplies. Patterns often follow a rule like this.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: How do we find the area of a square? ||| student: Do we add the sides? ||| teacher: Almost, but there's a specific operation here.",
        "Expert_Human_Tutor": "You actually multiply the length by itself, since area measures the space inside.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: When you divide, what happens to a number? ||| student: It gets smaller. ||| teacher: Correct! Let’s see why.",
        "Expert_Human_Tutor": "Division is about splitting into equal parts. This is why the result is smaller.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Think of an angle as part of a circle. ||| student: How much is in a full circle? ||| teacher: Good question, let’s look.",
        "Expert_Human_Tutor": "A full circle has 360 degrees. We measure each angle as a portion of that.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Imagine folding paper to make shapes. ||| student: Like origami? ||| teacher: Exactly! How does folding relate to symmetry?",
        "Expert_Human_Tutor": "Symmetry means one half mirrors the other. Folding helps you see if both sides match.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Let’s count by twos. ||| student: Two, four, six… ||| teacher: Great! Do you notice a pattern?",
        "Expert_Human_Tutor": "Counting by twos skips every other number, creating a pattern of even numbers.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What is a fraction? ||| student: Part of a whole? ||| teacher: Yes, let’s explore how we represent parts.",
        "Expert_Human_Tutor": "A fraction has two parts: the numerator and denominator, which show how many parts we have and out of what total.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Here’s a list of even numbers. ||| student: They all end in 0, 2, 4, 6, or 8. ||| teacher: That’s right! Let’s discuss why.",
        "Expert_Human_Tutor": "Ending in those digits means a number divides by 2, making it even.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What do you know about volume? ||| student: It’s like area? ||| teacher: Close. Let's clarify the difference.",
        "Expert_Human_Tutor": "Volume measures three-dimensional space inside an object, unlike area, which measures two-dimensional space.",
        "Peda_Strategies": "explain_concept"
    }
]

# Convert new entries into a DataFrame
new_df_2 = pd.DataFrame(new_entries_2)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_2], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New entries added successfully!")
# Out:
# New entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added
new_entries_3 = [
    {
        "History": "||| teacher: How would you describe a rectangle? ||| student: It has four sides. ||| teacher: Good! And what about its angles?",
        "Expert_Human_Tutor": "A rectangle has four sides and four right angles, which makes it a special type of quadrilateral.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What happens when you subtract a smaller number from a larger one? ||| student: The answer is smaller. ||| teacher: Yes, let’s discuss why.",
        "Expert_Human_Tutor": "Subtracting means taking away. When you take away less than you have, it leaves a smaller amount.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Let’s talk about multiplication tables. ||| student: I know some of them. ||| teacher: Great! What do you notice about the patterns?",
        "Expert_Human_Tutor": "Multiplication tables show repeated addition. For example, 3 x 4 means adding 3 four times.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: When we talk about temperature, what do you think of? ||| student: Hot or cold. ||| teacher: Exactly! And how do we measure it?",
        "Expert_Human_Tutor": "Temperature is measured in degrees, showing how hot or cold something is relative to a standard scale.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Think of a circle’s diameter. ||| student: It’s across the middle, right? ||| teacher: Yes! Let’s explain that further.",
        "Expert_Human_Tutor": "The diameter is a straight line passing through the center and touching both sides of the circle.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What does it mean to estimate? ||| student: To guess? ||| teacher: Sort of. Let's make it clearer.",
        "Expert_Human_Tutor": "Estimation means finding an answer close to the exact one, often by rounding or using approximate values.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Do you know what an average is? ||| student: It’s the middle? ||| teacher: Close! Let’s go through the steps.",
        "Expert_Human_Tutor": "The average is the sum of numbers divided by the count, giving a central value.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: How do we measure length? ||| student: With a ruler? ||| teacher: Yes, and what units can we use?",
        "Expert_Human_Tutor": "Length can be measured in units like inches, centimeters, or meters, depending on the context.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Let’s discuss perimeter. ||| student: It’s around the edge? ||| teacher: Exactly. Let’s clarify.",
        "Expert_Human_Tutor": "Perimeter is the total distance around a shape, found by adding up all its sides.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What do we mean by a sequence in math? ||| student: A series of numbers? ||| teacher: Yes, with a specific order.",
        "Expert_Human_Tutor": "A sequence follows a rule, like adding or multiplying to get each successive number.",
        "Peda_Strategies": "explain_concept"
    }
]

# Convert new entries into a DataFrame
new_df_3 = pd.DataFrame(new_entries_3)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_3], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New entries added successfully!")
# Out:
# New entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_example' pedagogical strategy
new_entries_4 = [
    {
        "History": "||| teacher: Let’s look at an example of a simple addition problem. ||| student: Okay, I’m ready. ||| teacher: What’s 5 + 3?",
        "Expert_Human_Tutor": "Imagine you have 5 apples, and you add 3 more. In total, you’d have 8 apples.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example with fractions. ||| student: I get confused with fractions. ||| teacher: No worries. What is 1/2 + 1/4?",
        "Expert_Human_Tutor": "Think of a pizza cut into parts. If you take half and add a quarter, you’ll have 3/4 of the pizza.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s try an example of multiplication. ||| student: Alright! ||| teacher: What’s 4 times 3?",
        "Expert_Human_Tutor": "Imagine 4 groups of 3 apples. Altogether, you have 12 apples.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example of finding the area. ||| student: Sounds good. ||| teacher: If a rectangle is 5 cm long and 3 cm wide, what’s the area?",
        "Expert_Human_Tutor": "Multiply 5 by 3 to get 15 cm², which is the space inside the rectangle.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s look at another example. ||| student: Sure! ||| teacher: If you have 10 apples and give away 3, how many do you have left?",
        "Expert_Human_Tutor": "10 minus 3 leaves you with 7 apples. This is a subtraction example.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s practice with a division example. ||| student: Okay! ||| teacher: If you split 12 cookies among 4 friends, how many cookies does each person get?",
        "Expert_Human_Tutor": "Each person gets 3 cookies since 12 divided by 4 is 3.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example with decimals. ||| student: Go ahead. ||| teacher: What is 0.5 plus 0.3?",
        "Expert_Human_Tutor": "Adding 0.5 and 0.3 gives you 0.8, like combining 50 cents with 30 cents to get 80 cents.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s try converting a fraction to a decimal. ||| student: Alright! ||| teacher: What’s 3/4 as a decimal?",
        "Expert_Human_Tutor": "3/4 is equal to 0.75. Imagine dividing something into four parts and taking three.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s look at a real-life example of probability. ||| student: Sure. ||| teacher: If you flip a coin, what’s the probability of landing on heads?",
        "Expert_Human_Tutor": "The probability is 1/2 or 50%, as there are two outcomes and one is heads.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example of rounding. ||| student: Okay! ||| teacher: If you have 5.6, what would it be rounded to the nearest whole number?",
        "Expert_Human_Tutor": "5.6 rounds to 6 because it’s closer to 6 than to 5.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s try an example with negative numbers. ||| student: Sure! ||| teacher: What’s -3 plus 5?",
        "Expert_Human_Tutor": "Adding 5 to -3 brings you to 2 on the number line.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example of using exponents. ||| student: Go ahead. ||| teacher: What is 2 raised to the power of 3?",
        "Expert_Human_Tutor": "2 to the power of 3 means 2 multiplied by itself three times: 2 x 2 x 2, which equals 8.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s work with an example involving units. ||| student: Sounds good. ||| teacher: If a car travels 60 km in an hour, what is its speed?",
        "Expert_Human_Tutor": "The speed is 60 km/h, meaning the car goes 60 kilometers in each hour.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example with percentages. ||| student: Okay! ||| teacher: If you have 20 out of 100, what percent do you have?",
        "Expert_Human_Tutor": "20 out of 100 is 20%, as it represents 20 parts of the whole 100.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s try an example with ratios. ||| student: Sure! ||| teacher: If you have 2 red balls and 3 blue balls, what’s the ratio of red to blue?",
        "Expert_Human_Tutor": "The ratio is 2:3, showing there are 2 red balls for every 3 blue ones.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example for converting units. ||| student: Alright. ||| teacher: If you have 100 cm, how many meters is that?",
        "Expert_Human_Tutor": "100 cm is equal to 1 meter, as there are 100 centimeters in a meter.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s try a geometry example. ||| student: Sure! ||| teacher: If a triangle has sides of 3, 4, and 5, is it a right triangle?",
        "Expert_Human_Tutor": "Yes, it’s a right triangle, as 3² + 4² equals 5², satisfying the Pythagorean theorem.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example with integers. ||| student: Go ahead. ||| teacher: What’s -7 minus 2?",
        "Expert_Human_Tutor": "Subtracting 2 from -7 gives -9, as you’re moving further left on the number line.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s look at an example of simplifying fractions. ||| student: Sure! ||| teacher: How can we simplify 8/12?",
        "Expert_Human_Tutor": "8/12 simplifies to 2/3 by dividing both the numerator and denominator by 4.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example of order of operations. ||| student: Okay! ||| teacher: What’s 3 + 5 × 2?",
        "Expert_Human_Tutor": "Using order of operations, you do the multiplication first: 5 × 2 = 10, then add 3 to get 13.",
        "Peda_Strategies": "provide_example"
    }
]

# Convert new entries into a DataFrame
new_df_4 = pd.DataFrame(new_entries_4)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_4], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New entries added successfully!")
# Out:
# New entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_example' pedagogical strategy
new_entries_5 = [
    {
        "History": "||| teacher: Let’s start with an example of addition. ||| student: Alright. ||| teacher: What’s 7 + 5?",
        "Expert_Human_Tutor": "If you have 7 pencils and add 5 more, you’d have a total of 12 pencils.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s do an example of finding the average. ||| student: Okay! ||| teacher: What’s the average of 4, 8, and 12?",
        "Expert_Human_Tutor": "Add them up to get 24, then divide by 3. So, the average is 8.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s try an example with percentages. ||| student: Sure! ||| teacher: What is 15% of 200?",
        "Expert_Human_Tutor": "15% of 200 is 30. You find this by multiplying 200 by 0.15.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s use an example with probability. ||| student: Sounds good! ||| teacher: What’s the probability of rolling a 4 on a six-sided die?",
        "Expert_Human_Tutor": "The probability is 1 out of 6, since there’s one 4 and six possible outcomes.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example using ratios. ||| student: Okay! ||| teacher: If a recipe calls for 2 cups of flour and 3 cups of sugar, what’s the ratio of flour to sugar?",
        "Expert_Human_Tutor": "The ratio of flour to sugar is 2:3, meaning you use 2 parts flour for every 3 parts sugar.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s try an example with time. ||| student: Sure. ||| teacher: If it’s 3 PM and you need to wait 2 hours, what time will it be?",
        "Expert_Human_Tutor": "Adding 2 hours to 3 PM brings you to 5 PM.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example using the concept of perimeter. ||| student: Alright! ||| teacher: What’s the perimeter of a rectangle with sides of 4 cm and 6 cm?",
        "Expert_Human_Tutor": "Add up all four sides: 4 + 6 + 4 + 6 to get a perimeter of 20 cm.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s look at an example of subtraction. ||| student: Go ahead. ||| teacher: What’s 15 minus 7?",
        "Expert_Human_Tutor": "If you start with 15 items and take away 7, you’re left with 8.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example of rounding numbers. ||| student: Sure! ||| teacher: Round 73 to the nearest ten.",
        "Expert_Human_Tutor": "73 rounds to 70, as it’s closer to 70 than to 80.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s work with an example of exponents. ||| student: Alright! ||| teacher: What’s 3 squared?",
        "Expert_Human_Tutor": "3 squared is 3 times 3, which equals 9.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s try an example with area. ||| student: Okay! ||| teacher: What’s the area of a square with sides of 5 cm?",
        "Expert_Human_Tutor": "The area is 5 times 5, which equals 25 cm².",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example using temperature. ||| student: Sounds good. ||| teacher: If it’s 10 degrees and rises by 15 degrees, what’s the new temperature?",
        "Expert_Human_Tutor": "The new temperature is 25 degrees, because 10 plus 15 equals 25.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s use an example of division. ||| student: Sure. ||| teacher: What’s 20 divided by 5?",
        "Expert_Human_Tutor": "20 divided by 5 gives you 4. It’s like sharing 20 items among 5 groups, with each getting 4.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example of decimal addition. ||| student: Okay! ||| teacher: What’s 0.7 plus 0.2?",
        "Expert_Human_Tutor": "0.7 plus 0.2 equals 0.9, like adding 70 cents and 20 cents to make 90 cents.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s look at an example with percentages. ||| student: Sure! ||| teacher: What’s 25% of 40?",
        "Expert_Human_Tutor": "25% of 40 is 10. You calculate it by multiplying 40 by 0.25.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example of the distributive property. ||| student: Alright! ||| teacher: What’s 3 × (4 + 2)?",
        "Expert_Human_Tutor": "Using the distributive property, 3 × 4 + 3 × 2 equals 12 + 6, which is 18.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s use an example of place value. ||| student: Sounds good. ||| teacher: What does the 5 represent in 350?",
        "Expert_Human_Tutor": "In 350, the 5 is in the tens place, so it represents 50.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example using addition. ||| student: Go ahead. ||| teacher: What’s 9 plus 6?",
        "Expert_Human_Tutor": "Adding 9 and 6 gives you 15.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s look at an example of estimating. ||| student: Okay! ||| teacher: About how much is 47 plus 52?",
        "Expert_Human_Tutor": "Rounding to the nearest ten, 47 becomes 50 and 52 becomes 50, so an estimate would be around 100.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example of finding the median. ||| student: Sure! ||| teacher: What’s the median of 3, 7, and 9?",
        "Expert_Human_Tutor": "Since 7 is the middle number, it’s the median.",
        "Peda_Strategies": "provide_example"
    }
]

# Convert new entries into a DataFrame
new_df_5 = pd.DataFrame(new_entries_5)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_5], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New entries added successfully!")
# Out:
# New entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_example' pedagogical strategy
new_entries = [
    {
        "History": "||| teacher: Let’s try an example using subtraction. ||| student: Alright! ||| teacher: What’s 20 - 8?",
        "Expert_Human_Tutor": "20 minus 8 equals 12. Imagine starting with 20 apples and taking away 8.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s do an example of multiplying by zero. ||| student: Okay! ||| teacher: What’s 7 times 0?",
        "Expert_Human_Tutor": "7 times 0 is 0, because any number multiplied by zero is always zero.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s try an example with fractions. ||| student: Sure! ||| teacher: What’s 1/3 of 9?",
        "Expert_Human_Tutor": "1/3 of 9 is 3, because dividing 9 into three equal parts gives you 3.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s use an example with order of operations. ||| student: Alright! ||| teacher: What’s 4 + 3 × 2?",
        "Expert_Human_Tutor": "Following order of operations, 3 × 2 is 6, then add 4 to get 10.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example of rounding to the nearest hundred. ||| student: Okay! ||| teacher: What would 842 round to?",
        "Expert_Human_Tutor": "842 rounds to 800, as it’s closer to 800 than 900.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s try converting a percentage to a fraction. ||| student: Sounds good! ||| teacher: What’s 25% as a fraction?",
        "Expert_Human_Tutor": "25% as a fraction is 1/4, because 25 out of 100 simplifies to 1/4.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s work with an example involving decimals. ||| student: Sure! ||| teacher: What’s 0.4 × 10?",
        "Expert_Human_Tutor": "0.4 times 10 equals 4, like moving the decimal one place to the right.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example with negative numbers. ||| student: Alright! ||| teacher: What’s -5 plus 3?",
        "Expert_Human_Tutor": "Starting at -5 and adding 3 brings you to -2 on the number line.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s do an example of finding the square of a number. ||| student: Sounds good. ||| teacher: What’s the square of 6?",
        "Expert_Human_Tutor": "6 squared, or 6 times 6, equals 36.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example of a decimal to fraction conversion. ||| student: Okay! ||| teacher: What is 0.75 as a fraction?",
        "Expert_Human_Tutor": "0.75 is 3/4 as a fraction, since 75 over 100 simplifies to 3/4.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s try an example with probability. ||| student: Sure! ||| teacher: What’s the probability of picking a red marble if you have 1 red and 3 blue marbles?",
        "Expert_Human_Tutor": "The probability is 1 out of 4, since there’s only 1 red marble out of a total of 4.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example with division. ||| student: Alright! ||| teacher: What’s 15 divided by 3?",
        "Expert_Human_Tutor": "15 divided by 3 is 5, as 3 goes into 15 exactly 5 times.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s try an example with units of measurement. ||| student: Okay! ||| teacher: If you have 1 meter, how many centimeters is that?",
        "Expert_Human_Tutor": "1 meter equals 100 centimeters.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example with multiples. ||| student: Alright! ||| teacher: What are the first three multiples of 4?",
        "Expert_Human_Tutor": "The first three multiples of 4 are 4, 8, and 12.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s use an example with percent increase. ||| student: Sounds good. ||| teacher: If a price goes from $50 to $60, what’s the percent increase?",
        "Expert_Human_Tutor": "The increase is $10, and $10 out of $50 is a 20% increase.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example of an odd number. ||| student: Okay! ||| teacher: Is 7 an odd number?",
        "Expert_Human_Tutor": "Yes, 7 is an odd number because it doesn’t divide evenly by 2.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s try an example with even numbers. ||| student: Sure. ||| teacher: Is 8 an even number?",
        "Expert_Human_Tutor": "Yes, 8 is even because it divides evenly by 2.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example with perimeter. ||| student: Okay! ||| teacher: What’s the perimeter of a square with each side 4 cm?",
        "Expert_Human_Tutor": "The perimeter is 4 times 4, which equals 16 cm.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Let’s try an example with place value. ||| student: Alright. ||| teacher: What does the 6 represent in 647?",
        "Expert_Human_Tutor": "In 647, the 6 is in the hundreds place, so it represents 600.",
        "Peda_Strategies": "provide_example"
    },
    {
        "History": "||| teacher: Here’s an example of combining fractions. ||| student: Sure! ||| teacher: What’s 1/4 plus 1/4?",
        "Expert_Human_Tutor": "1/4 plus 1/4 is 2/4, which simplifies to 1/2.",
        "Peda_Strategies": "provide_example"
    }
]

# Convert new entries into a DataFrame
new_df = pd.DataFrame(new_entries)

# Append new entries to the existing dataset
df = pd.concat([df, new_df], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New entries added successfully!")
# Out:
# New entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'affirm_correct_answer' pedagogical strategy
new_entries_affirm = [
    {
        "History": "||| teacher: What’s 3 + 5? ||| student: 8 ||| teacher: Great job!",
        "Expert_Human_Tutor": "That’s correct! You got it exactly right.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: Can you tell me the product of 7 and 6? ||| student: 42 ||| teacher: Exactly!",
        "Expert_Human_Tutor": "Yes, 42 is the correct answer! Well done.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 15 divided by 3? ||| student: 5 ||| teacher: Correct!",
        "Expert_Human_Tutor": "Good job! 5 is the correct answer.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the square root of 36? ||| student: 6 ||| teacher: Nicely done!",
        "Expert_Human_Tutor": "Perfect answer, 6 is indeed correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: If you subtract 4 from 10, what do you get? ||| student: 6 ||| teacher: That’s right!",
        "Expert_Human_Tutor": "Absolutely, you got it! 6 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s half of 20? ||| student: 10 ||| teacher: Yes!",
        "Expert_Human_Tutor": "Good thinking, 10 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the value of 9 times 3? ||| student: 27 ||| teacher: Correct answer!",
        "Expert_Human_Tutor": "Great job! 27 is exactly right.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 100 divided by 10? ||| student: 10 ||| teacher: Exactly!",
        "Expert_Human_Tutor": "Yes, that’s correct. Nicely done!",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 12 plus 8? ||| student: 20 ||| teacher: Yes, that’s right!",
        "Expert_Human_Tutor": "Perfect! 20 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: Can you find the area of a rectangle with sides 4 and 5? ||| student: 20 ||| teacher: Good job!",
        "Expert_Human_Tutor": "That’s exactly right! The area is 20.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the next number after 14? ||| student: 15 ||| teacher: Correct!",
        "Expert_Human_Tutor": "Nice job, 15 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 3/4 as a decimal? ||| student: 0.75 ||| teacher: Yes, that’s right!",
        "Expert_Human_Tutor": "Well done, 0.75 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the sum of 11 and 7? ||| student: 18 ||| teacher: Exactly!",
        "Expert_Human_Tutor": "Great answer, 18 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the remainder when you divide 17 by 4? ||| student: 1 ||| teacher: Correct!",
        "Expert_Human_Tutor": "Right on! The remainder is 1.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 0.5 plus 0.3? ||| student: 0.8 ||| teacher: Perfect!",
        "Expert_Human_Tutor": "Yes, 0.8 is the correct answer. Nice work!",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: If you add 25 and 30, what do you get? ||| student: 55 ||| teacher: Good job!",
        "Expert_Human_Tutor": "Absolutely right! 55 is the answer.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 8 divided by 2? ||| student: 4 ||| teacher: Exactly!",
        "Expert_Human_Tutor": "Nice work, 4 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: Can you tell me what 6 times 6 is? ||| student: 36 ||| teacher: Yes!",
        "Expert_Human_Tutor": "Perfect answer! 36 is right.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 15 minus 7? ||| student: 8 ||| teacher: Correct!",
        "Expert_Human_Tutor": "Well done, 8 is the right answer.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 5 squared? ||| student: 25 ||| teacher: That’s right!",
        "Expert_Human_Tutor": "Great job, 25 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    }
]

# Convert new entries into a DataFrame
new_df_affirm = pd.DataFrame(new_entries_affirm)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_affirm], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New entries added successfully!")
# Out:
# New entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'affirm_correct_answer' pedagogical strategy
new_entries_affirm_2 = [
    {
        "History": "||| teacher: What’s the value of 8 + 9? ||| student: 17 ||| teacher: Exactly right!",
        "Expert_Human_Tutor": "Yes, 17 is spot-on. Great job!",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: If you multiply 5 by 5, what do you get? ||| student: 25 ||| teacher: Perfect!",
        "Expert_Human_Tutor": "That’s right! 25 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 20 minus 15? ||| student: 5 ||| teacher: Correct answer!",
        "Expert_Human_Tutor": "Nicely done! 5 is the right answer.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What is the square root of 49? ||| student: 7 ||| teacher: Yes, that’s correct!",
        "Expert_Human_Tutor": "Exactly! 7 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 18 divided by 6? ||| student: 3 ||| teacher: Right!",
        "Expert_Human_Tutor": "Good answer, 3 is exactly right!",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What is 9 times 4? ||| student: 36 ||| teacher: Well done!",
        "Expert_Human_Tutor": "Yes, 36 is absolutely correct!",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the next even number after 10? ||| student: 12 ||| teacher: That’s correct!",
        "Expert_Human_Tutor": "Great job! 12 is right.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: If you add 30 and 40, what do you get? ||| student: 70 ||| teacher: Exactly!",
        "Expert_Human_Tutor": "Perfect answer, 70 is right.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 7 minus 3? ||| student: 4 ||| teacher: Yes, that’s right!",
        "Expert_Human_Tutor": "Good work, 4 is the correct answer.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the product of 10 and 3? ||| student: 30 ||| teacher: Correct!",
        "Expert_Human_Tutor": "Nicely done, 30 is right.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 24 divided by 8? ||| student: 3 ||| teacher: Perfect answer!",
        "Expert_Human_Tutor": "Exactly right! 3 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the remainder when 10 is divided by 3? ||| student: 1 ||| teacher: Yes!",
        "Expert_Human_Tutor": "Good answer, the remainder is indeed 1.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 2 to the power of 3? ||| student: 8 ||| teacher: Correct!",
        "Expert_Human_Tutor": "Nice job! 8 is exactly right.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: If you subtract 9 from 18, what do you get? ||| student: 9 ||| teacher: Well done!",
        "Expert_Human_Tutor": "Yes, 9 is correct. Great work!",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 6 plus 6? ||| student: 12 ||| teacher: That’s right!",
        "Expert_Human_Tutor": "Great answer, 12 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What is 4 squared? ||| student: 16 ||| teacher: Correct!",
        "Expert_Human_Tutor": "Perfect, 16 is right.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: If you divide 25 by 5, what do you get? ||| student: 5 ||| teacher: Yes!",
        "Expert_Human_Tutor": "Exactly! 5 is the right answer.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 3/4 of 12? ||| student: 9 ||| teacher: Correct answer!",
        "Expert_Human_Tutor": "Nice job! 9 is spot-on.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the next odd number after 15? ||| student: 17 ||| teacher: Yes, that’s right!",
        "Expert_Human_Tutor": "Good thinking! 17 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: If you add 12 and 15, what do you get? ||| student: 27 ||| teacher: Well done!",
        "Expert_Human_Tutor": "Perfect answer, 27 is correct!",
        "Peda_Strategies": "affirm_correct_answer"
    }
]

# Convert new entries into a DataFrame
new_df_affirm_2 = pd.DataFrame(new_entries_affirm_2)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_affirm_2], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New entries added successfully!")
# Out:
# New entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'affirm_correct_answer' pedagogical strategy
new_entries_affirm_3 = [
    {
        "History": "||| teacher: What’s 14 + 6? ||| student: 20 ||| teacher: Absolutely correct!",
        "Expert_Human_Tutor": "Great job! 20 is exactly right.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: If you have 3 quarters, what’s the total in cents? ||| student: 75 ||| teacher: Perfect!",
        "Expert_Human_Tutor": "Yes, 75 cents is correct!",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 100 minus 75? ||| student: 25 ||| teacher: Exactly!",
        "Expert_Human_Tutor": "Good work! 25 is the right answer.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: If 5 times what number equals 45? ||| student: 9 ||| teacher: Correct!",
        "Expert_Human_Tutor": "Spot-on! 9 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 9 plus 11? ||| student: 20 ||| teacher: Nicely done!",
        "Expert_Human_Tutor": "Yes, 20 is right. Well done!",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the area of a square with side 4 cm? ||| student: 16 ||| teacher: Exactly!",
        "Expert_Human_Tutor": "Perfect answer! 16 cm² is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: If you divide 36 by 6, what’s the result? ||| student: 6 ||| teacher: That’s right!",
        "Expert_Human_Tutor": "Good answer, 6 is exactly right!",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the next multiple of 3 after 12? ||| student: 15 ||| teacher: Yes, that’s it!",
        "Expert_Human_Tutor": "Great thinking! 15 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: If you add 7 and 9, what do you get? ||| student: 16 ||| teacher: Right answer!",
        "Expert_Human_Tutor": "Nice job! 16 is the correct result.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the value of 6 cubed? ||| student: 216 ||| teacher: Perfect!",
        "Expert_Human_Tutor": "Yes, 216 is correct. Well done!",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: If you subtract 3 from 8, what do you get? ||| student: 5 ||| teacher: Correct!",
        "Expert_Human_Tutor": "Good answer, 5 is right.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the remainder when 20 is divided by 6? ||| student: 2 ||| teacher: Yes!",
        "Expert_Human_Tutor": "Exactly right, the remainder is 2.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the result of 2 to the power of 5? ||| student: 32 ||| teacher: Well done!",
        "Expert_Human_Tutor": "Perfect! 32 is the correct answer.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: If you have 10 tens, what’s the total? ||| student: 100 ||| teacher: Exactly!",
        "Expert_Human_Tutor": "Yes, 100 is correct!",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 12 times 2? ||| student: 24 ||| teacher: Right answer!",
        "Expert_Human_Tutor": "Nicely done! 24 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s half of 14? ||| student: 7 ||| teacher: That’s correct!",
        "Expert_Human_Tutor": "Yes, 7 is exactly right.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 0.25 as a fraction? ||| student: 1/4 ||| teacher: Correct!",
        "Expert_Human_Tutor": "Well done, 1/4 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the square of 11? ||| student: 121 ||| teacher: Absolutely right!",
        "Expert_Human_Tutor": "Great work! 121 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: If you add 3/4 and 1/4, what’s the result? ||| student: 1 ||| teacher: Yes, that’s it!",
        "Expert_Human_Tutor": "Perfect! 1 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the next odd number after 23? ||| student: 25 ||| teacher: Correct!",
        "Expert_Human_Tutor": "Great thinking, 25 is right.",
        "Peda_Strategies": "affirm_correct_answer"
    }
]

# Convert new entries into a DataFrame
new_df_affirm_3 = pd.DataFrame(new_entries_affirm_3)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_affirm_3], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New entries added successfully!")
# Out:
# New entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'affirm_correct_answer' pedagogical strategy
new_entries_affirm_4 = [
    {
        "History": "||| teacher: What’s the sum of 18 and 2? ||| student: 20 ||| teacher: Absolutely right!",
        "Expert_Human_Tutor": "Great job! 20 is the correct answer.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the product of 7 and 8? ||| student: 56 ||| teacher: Perfect!",
        "Expert_Human_Tutor": "Exactly, 56 is spot on!",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 21 divided by 7? ||| student: 3 ||| teacher: That’s correct!",
        "Expert_Human_Tutor": "Good work, 3 is the right answer!",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: If you subtract 10 from 25, what do you get? ||| student: 15 ||| teacher: Exactly!",
        "Expert_Human_Tutor": "Yes, 15 is correct. Well done!",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the square root of 81? ||| student: 9 ||| teacher: Yes, that’s correct!",
        "Expert_Human_Tutor": "Perfect answer! 9 is right.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 3 times 5? ||| student: 15 ||| teacher: Correct answer!",
        "Expert_Human_Tutor": "Nice job! 15 is the correct answer.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the next number after 29? ||| student: 30 ||| teacher: Exactly!",
        "Expert_Human_Tutor": "Yes, 30 is the next number. Great job!",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 100 minus 25? ||| student: 75 ||| teacher: Right!",
        "Expert_Human_Tutor": "Good thinking! 75 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 4 squared? ||| student: 16 ||| teacher: That’s right!",
        "Expert_Human_Tutor": "Excellent! 16 is the correct answer.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 10 times 6? ||| student: 60 ||| teacher: Correct!",
        "Expert_Human_Tutor": "Yes, 60 is right. Nice job!",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 7 plus 13? ||| student: 20 ||| teacher: Yes, correct!",
        "Expert_Human_Tutor": "Perfect! 20 is the answer.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 5 times 12? ||| student: 60 ||| teacher: Exactly!",
        "Expert_Human_Tutor": "Great answer, 60 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 1/2 of 16? ||| student: 8 ||| teacher: That’s correct!",
        "Expert_Human_Tutor": "Nicely done! 8 is exactly right.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the next even number after 16? ||| student: 18 ||| teacher: Perfect!",
        "Expert_Human_Tutor": "Great job! 18 is right.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the area of a rectangle with length 5 and width 3? ||| student: 15 ||| teacher: Correct answer!",
        "Expert_Human_Tutor": "Exactly right! 15 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 40 divided by 8? ||| student: 5 ||| teacher: Right!",
        "Expert_Human_Tutor": "Good work! 5 is the correct answer.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 9 times 5? ||| student: 45 ||| teacher: Yes, that’s right!",
        "Expert_Human_Tutor": "Perfect answer! 45 is spot-on.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 6 added to 7? ||| student: 13 ||| teacher: Correct!",
        "Expert_Human_Tutor": "Nice job! 13 is the correct result.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s 3 cubed? ||| student: 27 ||| teacher: Absolutely right!",
        "Expert_Human_Tutor": "Great thinking! 27 is correct.",
        "Peda_Strategies": "affirm_correct_answer"
    },
    {
        "History": "||| teacher: What’s the remainder when 15 is divided by 4? ||| student: 3 ||| teacher: Yes!",
        "Expert_Human_Tutor": "Exactly right, the remainder is 3.",
        "Peda_Strategies": "affirm_correct_answer"
    }
]

# Convert new entries into a DataFrame
new_df_affirm_4 = pd.DataFrame(new_entries_affirm_4)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_affirm_4], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New entries added successfully!")
# Out:
# New entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_similar_problem' pedagogical strategy
new_entries_similar_4 = [
    {
        "History": "||| teacher: If you understand 5 + 3, try a similar one: What’s 6 + 2? ||| student: I’ll give it a try.",
        "Expert_Human_Tutor": "Good! Solving this similar problem will help reinforce the addition concept.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Great work on finding the product of 7 × 4. Now, can you try 6 × 5? ||| student: Okay!",
        "Expert_Human_Tutor": "Practicing with a similar multiplication problem will help strengthen your skills.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you solved 15 - 7 correctly, let’s try a similar problem: What’s 18 - 9? ||| student: Alright, I’ll try.",
        "Expert_Human_Tutor": "Yes, this subtraction example is a good follow-up to practice what you learned.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Now that you found the area of a rectangle, let’s try another with dimensions 6 and 8. ||| student: Got it.",
        "Expert_Human_Tutor": "Working through a similar problem will reinforce the concept of finding area.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Good job on dividing 20 by 4. Now, can you divide 25 by 5? ||| student: I’ll try!",
        "Expert_Human_Tutor": "This is another division problem that follows the same pattern.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you added 12 and 5, let’s try adding 14 and 6. ||| student: Sounds good.",
        "Expert_Human_Tutor": "This example is similar and helps practice adding larger numbers.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Great work on simplifying 3/6. Now, try simplifying 4/8. ||| student: I’ll give it a go.",
        "Expert_Human_Tutor": "This fraction is similar, so it’s good practice to see if you remember the steps.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: After solving 9 + 8, try 10 + 7 for a similar example. ||| student: Sure!",
        "Expert_Human_Tutor": "Practicing with similar numbers will help you see the addition pattern.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Now that you know how to find 1/3 of 9, try finding 1/3 of 12. ||| student: I’ll try that.",
        "Expert_Human_Tutor": "This similar example will help reinforce your understanding of fractions.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you solved 6 × 3, try solving 7 × 3 next. ||| student: Got it.",
        "Expert_Human_Tutor": "This multiplication problem follows the same pattern, so it’s good practice.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Great job calculating 45 ÷ 9. Now try 54 ÷ 9. ||| student: Okay!",
        "Expert_Human_Tutor": "This similar division problem helps strengthen the skill you just practiced.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Now that you solved for x in 2x = 8, let’s try 3x = 9. ||| student: Sounds good.",
        "Expert_Human_Tutor": "Working on a similar equation will help reinforce your solving skills.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you did well finding 1/4 of 16, now try finding 1/4 of 20. ||| student: I’ll give it a go.",
        "Expert_Human_Tutor": "Practicing with a similar fraction will help solidify your understanding.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Great job on finding the perimeter of a square with sides of 5. Now try it with sides of 6. ||| student: Got it.",
        "Expert_Human_Tutor": "This similar example will reinforce your understanding of finding perimeter.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Good work solving 8 - 2. Now, try 10 - 3. ||| student: I’ll try!",
        "Expert_Human_Tutor": "This example uses the same steps and will help you practice subtraction.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Now that you found 50% of 100, let’s try 50% of 80. ||| student: Alright.",
        "Expert_Human_Tutor": "This is a similar problem to help you reinforce your understanding of percentages.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you solved for 3x = 12, now try 4x = 16. ||| student: Okay!",
        "Expert_Human_Tutor": "Solving similar equations will help you get more comfortable with this type of problem.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: After calculating 10 × 4, try 11 × 4 as a similar problem. ||| student: Sure.",
        "Expert_Human_Tutor": "This is another multiplication problem that will reinforce what you learned.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Now that you added 5.5 + 3.2, let’s try 6.5 + 2.8. ||| student: Got it!",
        "Expert_Human_Tutor": "This is a similar addition problem to give you more practice.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Great work on finding 2/5 of 10. Now try 2/5 of 15. ||| student: I’ll give it a go.",
        "Expert_Human_Tutor": "This similar problem will help reinforce your understanding of fractions.",
        "Peda_Strategies": "provide_similar_problem"
    }
]

# Convert new entries into a DataFrame
new_df_similar_4 = pd.DataFrame(new_entries_similar_4)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_similar_4], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New entries added successfully!")
# Out:
# New entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_similar_problem' pedagogical strategy
new_entries_similar_5 = [
    {
        "History": "||| teacher: You did well on 10 + 6. Now, try 12 + 8. ||| student: Okay!",
        "Expert_Human_Tutor": "This similar problem helps you practice adding slightly larger numbers.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you found 1/2 of 18, let’s try 1/2 of 24. ||| student: Got it.",
        "Expert_Human_Tutor": "This is a similar fraction problem to reinforce your understanding of halving.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Great job on 20 ÷ 4. Now, let’s try 24 ÷ 4. ||| student: Sounds good.",
        "Expert_Human_Tutor": "Working on this similar division problem will help solidify your division skills.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you successfully multiplied 3 × 8, now try 3 × 9. ||| student: Sure!",
        "Expert_Human_Tutor": "This is another multiplication example to reinforce the same concept.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Good work on finding 30% of 50. Now, can you find 30% of 60? ||| student: I’ll give it a go.",
        "Expert_Human_Tutor": "Practicing with a similar percentage problem helps deepen your understanding.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Great job with 4 × 6. Now try 5 × 6. ||| student: Okay!",
        "Expert_Human_Tutor": "This similar multiplication problem will help you strengthen your skill.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: After solving for x in x + 3 = 7, try x + 4 = 8. ||| student: Got it.",
        "Expert_Human_Tutor": "Solving a similar equation will reinforce your algebra skills.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: You did well with 2/5 of 20. Now, find 2/5 of 25. ||| student: Alright.",
        "Expert_Human_Tutor": "This similar fraction problem will help you practice your understanding of proportions.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you calculated the perimeter of a square with sides of 4, now find the perimeter of a square with sides of 7. ||| student: Sounds good.",
        "Expert_Human_Tutor": "This similar problem lets you apply the same perimeter formula to different values.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Great work finding 10% of 100. Now, try finding 10% of 80. ||| student: Okay!",
        "Expert_Human_Tutor": "This similar percentage problem helps reinforce your understanding of calculating percentages.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you handled 7 + 5 well, try 8 + 6. ||| student: Sure, I’ll try.",
        "Expert_Human_Tutor": "Practicing with a similar addition problem will build confidence with larger numbers.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Good job finding 1/3 of 9. Now, can you find 1/3 of 12? ||| student: I’ll give it a shot.",
        "Expert_Human_Tutor": "This similar fraction problem helps reinforce your understanding of thirds.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: After solving 6 × 4, let’s try 7 × 4. ||| student: Sounds good.",
        "Expert_Human_Tutor": "This similar multiplication problem will help you become even more confident in multiplying.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you found the area of a rectangle with sides 5 and 10, try a rectangle with sides 6 and 9. ||| student: Okay!",
        "Expert_Human_Tutor": "This similar area problem will strengthen your understanding of the area calculation.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you successfully added 25 and 15, try adding 30 and 20. ||| student: Got it.",
        "Expert_Human_Tutor": "This similar addition problem will reinforce your mental math skills.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Good job on 8 divided by 2. Now, try 12 divided by 3. ||| student: I’ll try that.",
        "Expert_Human_Tutor": "This similar division problem helps you practice dividing by different numbers.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you calculated 3/5 of 10, let’s try 3/5 of 15. ||| student: Sure!",
        "Expert_Human_Tutor": "Working through a similar fraction problem will reinforce your skills.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Great work on 20 + 15. Now, can you try 25 + 10? ||| student: Got it.",
        "Expert_Human_Tutor": "This similar addition problem gives you more practice with mental calculations.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you solved 12 × 2, try 14 × 2. ||| student: I’ll give it a go!",
        "Expert_Human_Tutor": "This similar multiplication problem will build confidence in your multiplication skills.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Good job finding the perimeter of a triangle with sides 3, 4, and 5. Now, try one with sides 5, 6, and 7. ||| student: Alright!",
        "Expert_Human_Tutor": "This similar perimeter problem allows you to apply the same concepts to different values.",
        "Peda_Strategies": "provide_similar_problem"
    }
]

# Convert new entries into a DataFrame
new_df_similar_5 = pd.DataFrame(new_entries_similar_5)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_similar_5], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New entries added successfully!")
# Out:
# New entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_similar_problem' pedagogical strategy
new_entries_similar_6 = [
    {
        "History": "||| teacher: Since you added 11 + 4, let’s try 13 + 5. ||| student: Okay!",
        "Expert_Human_Tutor": "This similar addition will help you practice adding numbers just a bit larger.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Great job finding the sum of 25 and 35. Now, let’s try adding 30 and 45. ||| student: Got it.",
        "Expert_Human_Tutor": "Working through this similar problem will reinforce addition with larger numbers.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you successfully divided 15 by 5, let’s try dividing 20 by 4. ||| student: I’ll try.",
        "Expert_Human_Tutor": "Practicing similar division problems will make you more comfortable with these types of calculations.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Good job calculating 2/3 of 12. Now, can you find 2/3 of 15? ||| student: Sounds good!",
        "Expert_Human_Tutor": "This similar fraction problem will help you understand how to work with different numbers.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: You did well finding 10% of 50. Now try finding 15% of 60. ||| student: Okay!",
        "Expert_Human_Tutor": "This similar percentage problem will give you practice calculating percentages of different amounts.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Great job on solving x - 4 = 10. Now, can you solve x - 5 = 15? ||| student: Sure!",
        "Expert_Human_Tutor": "This similar algebra problem helps reinforce your equation-solving skills.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you multiplied 6 by 5, try multiplying 7 by 5. ||| student: Got it.",
        "Expert_Human_Tutor": "This similar multiplication will strengthen your skills with consistent practice.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: After finding the perimeter of a square with sides of 3, let’s try one with sides of 8. ||| student: Okay.",
        "Expert_Human_Tutor": "Practicing with a similar perimeter calculation helps reinforce the formula you used.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you calculated 4 + 6, let’s try 5 + 7. ||| student: Sure, I’ll try.",
        "Expert_Human_Tutor": "This similar problem is great for practicing addition with slightly larger numbers.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: You found 20% of 80 well. Now, try finding 20% of 90. ||| student: Alright!",
        "Expert_Human_Tutor": "This similar problem reinforces your understanding of calculating percentages.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: After solving 3x = 15, let’s try solving 3x = 18. ||| student: Sounds good.",
        "Expert_Human_Tutor": "This similar equation will give you more confidence in solving for x.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you successfully calculated 5 × 4, try solving 6 × 4. ||| student: I’ll give it a shot.",
        "Expert_Human_Tutor": "This similar multiplication problem will help reinforce your skills with basic multiplication.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Good job on finding 1/5 of 10. Now try 1/5 of 15. ||| student: Got it!",
        "Expert_Human_Tutor": "This similar problem will build your confidence with fractions and proportional reasoning.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you solved 25 ÷ 5, now try 30 ÷ 5. ||| student: Sure.",
        "Expert_Human_Tutor": "This similar division example will reinforce your understanding of division.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: After finding the area of a rectangle with sides of 7 and 5, try one with sides of 9 and 6. ||| student: Okay!",
        "Expert_Human_Tutor": "This similar problem helps you practice finding area with different dimensions.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: You did well on 7 + 9. Now, try 8 + 10. ||| student: Sounds good.",
        "Expert_Human_Tutor": "This addition problem follows a similar pattern, helping reinforce your skills with sums.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you solved 2/3 of 18, let’s try 2/3 of 21. ||| student: Got it.",
        "Expert_Human_Tutor": "This similar fraction problem helps build a solid understanding of proportions.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Good job with 50% of 30. Now, let’s try 50% of 40. ||| student: Alright!",
        "Expert_Human_Tutor": "Working through this similar problem helps reinforce percentage calculations.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you found the area of a triangle with base 5 and height 6, try one with base 7 and height 8. ||| student: I’ll try.",
        "Expert_Human_Tutor": "Practicing with a similar area problem will deepen your understanding of the area formula.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you successfully added 15 + 20, now try adding 18 + 22. ||| student: Sure, I’ll give it a go.",
        "Expert_Human_Tutor": "This similar addition problem helps reinforce your skills with adding larger numbers.",
        "Peda_Strategies": "provide_similar_problem"
    }
]

# Convert new entries into a DataFrame
new_df_similar_6 = pd.DataFrame(new_entries_similar_6)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_similar_6], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New entries added successfully!")
# Out:
# New entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_similar_problem' pedagogical strategy
new_entries_similar_7 = [
    {
        "History": "||| teacher: Now that you found the sum of 14 and 6, try finding the sum of 17 and 8. ||| student: Okay!",
        "Expert_Human_Tutor": "Practicing with similar addition problems like this will help solidify your skills.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you did well on 9 × 4, let’s try 10 × 4. ||| student: Got it.",
        "Expert_Human_Tutor": "This similar multiplication problem is perfect for strengthening your recall of multiplication facts.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: You successfully solved 50 divided by 10. Now, try 60 divided by 10. ||| student: Alright!",
        "Expert_Human_Tutor": "Practicing this similar division problem will reinforce your understanding of dividing by 10.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Great work finding 1/4 of 16. Now, can you try finding 1/4 of 20? ||| student: Sure!",
        "Expert_Human_Tutor": "This similar fraction problem will deepen your understanding of the concept of quarters.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: After calculating the perimeter of a rectangle with sides 5 and 10, try one with sides 7 and 9. ||| student: Got it.",
        "Expert_Human_Tutor": "This similar perimeter calculation will help you practice using the same formula with different numbers.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Now that you found the product of 6 and 5, try solving 7 and 5. ||| student: Alright!",
        "Expert_Human_Tutor": "This similar multiplication will help reinforce your accuracy with multiplication.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you found 15% of 100, let’s try 15% of 80. ||| student: Sounds good.",
        "Expert_Human_Tutor": "This similar percentage problem will further develop your skills with percentages.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Good job solving for x in x - 2 = 6. Now, try x - 3 = 7. ||| student: Okay!",
        "Expert_Human_Tutor": "This similar equation will help reinforce the steps to isolate x.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: You calculated 20 divided by 4 well. Now, try 25 divided by 5. ||| student: Sure, I’ll try.",
        "Expert_Human_Tutor": "This similar division problem helps reinforce your skills with basic division facts.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you added 14 + 9 correctly, now try 15 + 11. ||| student: Got it.",
        "Expert_Human_Tutor": "This similar addition will help build your confidence with slightly larger sums.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: After solving 12 - 5, try 14 - 6. ||| student: I’ll give it a go!",
        "Expert_Human_Tutor": "This similar subtraction problem lets you practice working with numbers in the same range.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Now that you calculated 3/4 of 16, try 3/4 of 20. ||| student: Alright.",
        "Expert_Human_Tutor": "This similar fraction problem helps reinforce understanding of working with three-fourths.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you found 2 × 9, now try 3 × 9. ||| student: Sounds good!",
        "Expert_Human_Tutor": "This similar multiplication helps reinforce consistent multiplication skills.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Good job with 15 + 12. Now, let’s try adding 18 + 15. ||| student: Sure!",
        "Expert_Human_Tutor": "Practicing similar addition problems will help you handle larger numbers with confidence.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: You solved x + 5 = 12 perfectly. Now, let’s try x + 6 = 14. ||| student: Got it.",
        "Expert_Human_Tutor": "This similar equation will help you become more confident with solving for x.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Great work on finding 1/3 of 12. Now, can you find 1/3 of 15? ||| student: Okay.",
        "Expert_Human_Tutor": "This similar fraction problem reinforces the concept of thirds.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: After finding the area of a square with side 5, try one with side 7. ||| student: Sure, I’ll try!",
        "Expert_Human_Tutor": "This similar area problem will help you practice using the area formula with different values.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you handled 8 + 7 well, now try adding 9 + 6. ||| student: Alright!",
        "Expert_Human_Tutor": "This addition problem with similar values will reinforce your addition skills.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Good job on finding 40% of 50. Now try finding 40% of 60. ||| student: I’ll give it a try.",
        "Expert_Human_Tutor": "This similar percentage problem will help deepen your understanding of how percentages work.",
        "Peda_Strategies": "provide_similar_problem"
    },
    {
        "History": "||| teacher: Since you found the product of 4 × 6, now try solving 5 × 6. ||| student: Got it.",
        "Expert_Human_Tutor": "This similar multiplication problem reinforces your familiarity with multiplication tables.",
        "Peda_Strategies": "provide_similar_problem"
    }
]

# Convert new entries into a DataFrame
new_df_similar_7 = pd.DataFrame(new_entries_similar_7)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_similar_7], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New entries added successfully!")
# Out:
# New entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_correction' pedagogical strategy
new_entries_correction = [
    {
        "History": "||| teacher: What’s 5 + 7? ||| student: 13 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "Close! But 5 + 7 equals 12. Give it another try.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: Can you tell me the product of 6 × 4? ||| student: 20 ||| teacher: Almost.",
        "Expert_Human_Tutor": "Actually, 6 times 4 is 24, not 20. Let’s try that again.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s half of 30? ||| student: 20 ||| teacher: Not exactly.",
        "Expert_Human_Tutor": "Half of 30 is 15. Give it another go!",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: Can you simplify 8/16? ||| student: 4/8 ||| teacher: Close, but not quite.",
        "Expert_Human_Tutor": "Actually, 8/16 simplifies to 1/2. Try it again with this correction.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 3 squared? ||| student: 6 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "3 squared means 3 × 3, which equals 9.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: How about 50 divided by 10? ||| student: 6 ||| teacher: Almost!",
        "Expert_Human_Tutor": "50 divided by 10 actually gives 5. Try that again.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 15 minus 9? ||| student: 7 ||| teacher: Very close.",
        "Expert_Human_Tutor": "Actually, 15 minus 9 is 6, not 7. Give it another try.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: Can you find the area of a square with sides of 4? ||| student: 8 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "The area is side × side, so 4 × 4 gives 16, not 8.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 7 times 7? ||| student: 48 ||| teacher: Close, but not exactly.",
        "Expert_Human_Tutor": "7 times 7 is actually 49. Try it again with this in mind.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 100 minus 35? ||| student: 55 ||| teacher: Almost there.",
        "Expert_Human_Tutor": "100 minus 35 is 65, not 55. Give it another try!",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 0.5 plus 0.5? ||| student: 0.10 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "Adding 0.5 and 0.5 gives 1.0, not 0.10.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the result of 20 divided by 5? ||| student: 3 ||| teacher: Almost.",
        "Expert_Human_Tutor": "20 divided by 5 equals 4, not 3. Give it another go.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the square root of 36? ||| student: 5 ||| teacher: Close!",
        "Expert_Human_Tutor": "Actually, the square root of 36 is 6, not 5. Try it once more.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 4/8 simplified? ||| student: 4/4 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "4/8 simplifies to 1/2. Let’s try that again.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: If you add 12 and 15, what’s the result? ||| student: 26 ||| teacher: Close, but not correct.",
        "Expert_Human_Tutor": "12 plus 15 is actually 27, not 26.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 5 to the power of 2? ||| student: 25 ||| teacher: Very close.",
        "Expert_Human_Tutor": "Actually, 5 squared is indeed 25. Great job!",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 10 times 2? ||| student: 25 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "10 times 2 equals 20, not 25.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 45 divided by 5? ||| student: 10 ||| teacher: Almost!",
        "Expert_Human_Tutor": "45 divided by 5 equals 9, not 10. Try that again.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 8 + 7? ||| student: 14 ||| teacher: Close!",
        "Expert_Human_Tutor": "8 plus 7 equals 15, not 14. Give it another try.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 6 times 8? ||| student: 42 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "6 times 8 actually equals 48, not 42.",
        "Peda_Strategies": "provide_correction"
    }
]

# Convert new entries into a DataFrame
new_df_correction = pd.DataFrame(new_entries_correction)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_correction], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New 'provide_correction' entries added successfully!")
# Out:
# New 'provide_correction' entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_correction' pedagogical strategy
new_entries_correction = [
    {
        "History": "||| teacher: What’s 4 + 9? ||| student: 14 ||| teacher: Close, but not quite.",
        "Expert_Human_Tutor": "Actually, 4 plus 9 is 13, not 14. Give it another try!",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 7 squared? ||| student: 42 ||| teacher: Almost.",
        "Expert_Human_Tutor": "7 squared means 7 × 7, which equals 49, not 42.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: Can you calculate 10% of 200? ||| student: 30 ||| teacher: Not exactly.",
        "Expert_Human_Tutor": "Actually, 10% of 200 is 20, not 30. Let’s give it another go!",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 18 minus 9? ||| student: 10 ||| teacher: Very close.",
        "Expert_Human_Tutor": "18 minus 9 is actually 9, not 10. Try it again!",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: If you double 12, what’s the result? ||| student: 20 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "Doubling 12 means 12 × 2, which equals 24.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the area of a rectangle with length 3 and width 5? ||| student: 18 ||| teacher: Close!",
        "Expert_Human_Tutor": "The area is 3 × 5, which equals 15, not 18.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the square root of 49? ||| student: 8 ||| teacher: Almost.",
        "Expert_Human_Tutor": "The square root of 49 is actually 7, not 8.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 3/4 of 16? ||| student: 10 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "3/4 of 16 is actually 12, not 10. Give it another try!",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 0.2 times 5? ||| student: 2 ||| teacher: Close, but incorrect.",
        "Expert_Human_Tutor": "0.2 times 5 actually equals 1, not 2.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: If you add 6 to 13, what do you get? ||| student: 18 ||| teacher: Close, but not quite.",
        "Expert_Human_Tutor": "Actually, 6 + 13 equals 19.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the value of 6 cubed? ||| student: 18 ||| teacher: Not exactly.",
        "Expert_Human_Tutor": "6 cubed means 6 × 6 × 6, which equals 216, not 18.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 25% of 80? ||| student: 30 ||| teacher: Almost there.",
        "Expert_Human_Tutor": "25% of 80 is actually 20, not 30. Try it again with this in mind!",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 100 divided by 4? ||| student: 40 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "Actually, 100 divided by 4 equals 25, not 40.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the perimeter of a square with sides of 7? ||| student: 28 ||| teacher: Very close!",
        "Expert_Human_Tutor": "Yes, the perimeter is 28. Good job!",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 8 divided by 4? ||| student: 1 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "Actually, 8 divided by 4 equals 2, not 1.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: Can you calculate 12 - 4? ||| student: 9 ||| teacher: Almost!",
        "Expert_Human_Tutor": "12 minus 4 equals 8, not 9.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the square of 8? ||| student: 15 ||| teacher: Not exactly.",
        "Expert_Human_Tutor": "The square of 8 is 64, not 15.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 5/10 simplified? ||| student: 5/5 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "5/10 simplifies to 1/2, not 5/5.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 20% of 200? ||| student: 50 ||| teacher: Very close.",
        "Expert_Human_Tutor": "Actually, 20% of 200 is 40, not 50.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 9 times 5? ||| student: 40 ||| teacher: Almost there.",
        "Expert_Human_Tutor": "9 times 5 is 45, not 40.",
        "Peda_Strategies": "provide_correction"
    }
]

# Convert new entries into a DataFrame
new_df_correction = pd.DataFrame(new_entries_correction)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_correction], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New 'provide_correction' entries added successfully!")
# Out:
# New 'provide_correction' entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_correction' pedagogical strategy
new_entries_correction = [
    {
        "History": "||| teacher: What is 9 multiplied by 3? ||| student: 21 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "Actually, 9 times 3 equals 27, not 21. Let's try that again.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is the sum of 14 and 8? ||| student: 23 ||| teacher: Close, but not exactly.",
        "Expert_Human_Tutor": "14 plus 8 is actually 22, not 23. Give it another try!",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is the value of 2 to the power of 4? ||| student: 6 ||| teacher: Almost.",
        "Expert_Human_Tutor": "2 to the power of 4 means 2 × 2 × 2 × 2, which equals 16, not 6.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is the perimeter of a rectangle with length 5 and width 3? ||| student: 15 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "The perimeter is calculated as 2 × (length + width), so 2 × (5 + 3) equals 16, not 15.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is 100 divided by 20? ||| student: 4 ||| teacher: Close!",
        "Expert_Human_Tutor": "Actually, 100 divided by 20 equals 5, not 4.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is the greatest common divisor of 9 and 15? ||| student: 5 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "The GCD of 9 and 15 is actually 3, not 5. Let's revisit how to find the GCD.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: Simplify the fraction 15/45. ||| student: 1/2 ||| teacher: Close, but not correct.",
        "Expert_Human_Tutor": "15/45 simplifies to 1/3, not 1/2.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is the square root of 81? ||| student: 8 ||| teacher: Almost there.",
        "Expert_Human_Tutor": "The square root of 81 is actually 9, not 8.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: Calculate the area of a triangle with base 10 and height 5. ||| student: 50 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "The area of a triangle is (base × height) ÷ 2, so (10 × 5) ÷ 2 equals 25, not 50.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is 7 minus 12? ||| student: 5 ||| teacher: Not exactly.",
        "Expert_Human_Tutor": "Subtracting a larger number from a smaller one gives a negative result. 7 minus 12 equals -5.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: Convert 0.75 to a fraction. ||| student: 3/5 ||| teacher: Close, but not correct.",
        "Expert_Human_Tutor": "0.75 as a fraction is 3/4, not 3/5.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is the value of 9 squared? ||| student: 72 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "9 squared is 9 × 9, which equals 81, not 72.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is 20% of 150? ||| student: 25 ||| teacher: Not exactly.",
        "Expert_Human_Tutor": "20% of 150 is actually 30, not 25.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: Solve for x: 3x = 12. ||| student: x = 5 ||| teacher: Close, but not correct.",
        "Expert_Human_Tutor": "To solve for x, divide both sides by 3. So x = 12 ÷ 3, which equals 4, not 5.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is the next prime number after 7? ||| student: 9 ||| teacher: Not exactly.",
        "Expert_Human_Tutor": "9 is not a prime number because it can be divided by 3. The next prime after 7 is actually 11.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is the circumference of a circle with a radius of 7? (Use π ≈ 3.14) ||| student: 21.98 ||| teacher: Close, but not correct.",
        "Expert_Human_Tutor": "The circumference is calculated as 2πr, so 2 × 3.14 × 7 equals approximately 43.96, not 21.98.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is 0 divided by any non-zero number? ||| student: Undefined ||| teacher: Not quite.",
        "Expert_Human_Tutor": "Actually, 0 divided by any non-zero number is 0. Division by zero is undefined, but 0 divided by a number is 0.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is the value of the expression 5 + 2 × 3? ||| student: 21 ||| teacher: Not exactly.",
        "Expert_Human_Tutor": "Remember the order of operations: multiplication before addition. So 2 × 3 = 6, then 5 + 6 = 11, not 21.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: If 2x + 3 = 11, what is x? ||| student: x = 6 ||| teacher: Almost.",
        "Expert_Human_Tutor": "Subtract 3 from both sides to get 2x = 8, then divide by 2 to find x = 4, not 6.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: Convert 25% to a decimal. ||| student: 2.5 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "25% as a decimal is 0.25, not 2.5.",
        "Peda_Strategies": "provide_correction"
    }
]

# Convert new entries into a DataFrame
new_df_correction = pd.DataFrame(new_entries_correction)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_correction], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New 'provide_correction' entries added successfully!")
# Out:
# New 'provide_correction' entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_correction' pedagogical strategy
new_entries_correction = [
    {
        "History": "||| teacher: What is the product of 4 and 6? ||| student: 26 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "Actually, 4 times 6 equals 24, not 26.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: How much is 50% of 120? ||| student: 70 ||| teacher: Close, but incorrect.",
        "Expert_Human_Tutor": "50% of 120 is 60, not 70. Let’s try it again!",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is the value of 4 cubed? ||| student: 24 ||| teacher: Not exactly.",
        "Expert_Human_Tutor": "4 cubed is 4 × 4 × 4, which equals 64, not 24.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: Simplify 18/24. ||| student: 3/4 ||| teacher: Very close!",
        "Expert_Human_Tutor": "Yes, 18/24 simplifies to 3/4. Good work!",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the next multiple of 7 after 21? ||| student: 29 ||| teacher: Almost there.",
        "Expert_Human_Tutor": "Actually, the next multiple of 7 after 21 is 28, not 29.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is 1/5 of 100? ||| student: 30 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "1/5 of 100 is actually 20, not 30.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: How much is 0.6 times 0.3? ||| student: 0.18 ||| teacher: Yes, correct.",
        "Expert_Human_Tutor": "Well done! 0.6 times 0.3 is indeed 0.18.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is the prime factorization of 12? ||| student: 2 × 3 ||| teacher: Almost correct.",
        "Expert_Human_Tutor": "The full prime factorization of 12 is 2 × 2 × 3.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: How much is 7 squared? ||| student: 45 ||| teacher: Close.",
        "Expert_Human_Tutor": "7 squared means 7 × 7, which equals 49, not 45.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is 30% of 200? ||| student: 75 ||| teacher: Not quite right.",
        "Expert_Human_Tutor": "30% of 200 is actually 60, not 75.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is the sum of 45 and 18? ||| student: 63 ||| teacher: Close, but not exactly.",
        "Expert_Human_Tutor": "45 plus 18 is 63. Nice work!",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is 5 divided by 0? ||| student: 0 ||| teacher: Not quite right.",
        "Expert_Human_Tutor": "Dividing by zero is actually undefined.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: Simplify 12/16. ||| student: 2/3 ||| teacher: Almost!",
        "Expert_Human_Tutor": "12/16 simplifies to 3/4, not 2/3.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the product of 11 and 2? ||| student: 24 ||| teacher: Not exactly.",
        "Expert_Human_Tutor": "11 times 2 is 22, not 24.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: How much is 0.25 times 8? ||| student: 3 ||| teacher: Almost.",
        "Expert_Human_Tutor": "0.25 times 8 is actually 2, not 3.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is 18 divided by 6? ||| student: 2 ||| teacher: Close.",
        "Expert_Human_Tutor": "18 divided by 6 is actually 3, not 2.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is 1/4 of 40? ||| student: 15 ||| teacher: Almost there.",
        "Expert_Human_Tutor": "1/4 of 40 is 10, not 15.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: How much is 5 squared? ||| student: 20 ||| teacher: Close, but not quite.",
        "Expert_Human_Tutor": "5 squared means 5 × 5, which equals 25.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: Simplify 24/36. ||| student: 2/3 ||| teacher: Correct!",
        "Expert_Human_Tutor": "Yes, 24/36 simplifies to 2/3. Great work!",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the square root of 64? ||| student: 7 ||| teacher: Close, but not quite.",
        "Expert_Human_Tutor": "The square root of 64 is actually 8, not 7.",
        "Peda_Strategies": "provide_correction"
    }
]

# Convert new entries into a DataFrame
new_df_correction = pd.DataFrame(new_entries_correction)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_correction], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New 'provide_correction' entries added successfully!")
# Out:
# New 'provide_correction' entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_strategy' pedagogical strategy
new_entries_strategy = [
    {
        "History": "||| teacher: What’s 15 + 7? ||| student: I’m not sure where to start.",
        "Expert_Human_Tutor": "Try adding the tens first, so 10 + 7, and then add the remaining 5. This way, you can break the addition down into easier steps.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can you simplify 8/12? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "A good strategy is to find the greatest common divisor of both numbers. In this case, divide both by 4.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s the area of a rectangle with sides 7 and 5? ||| student: I don’t remember the formula.",
        "Expert_Human_Tutor": "Think about the area formula: length × width. So here, you’d multiply 7 by 5.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: Can you solve 3x = 12? ||| student: I’m stuck.",
        "Expert_Human_Tutor": "Try isolating x by dividing both sides by 3. This way, you’ll have x by itself.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s 25% of 200? ||| student: I’m not sure where to start.",
        "Expert_Human_Tutor": "First, find 10% of 200 by dividing by 10. Then, you can double it to find 20% and add another 5%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can you calculate the perimeter of a square with side length 4? ||| student: I don’t know the steps.",
        "Expert_Human_Tutor": "Since a square has four equal sides, try multiplying the side length by 4 to find the perimeter.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s the next multiple of 3 after 12? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Think of multiples as repeated addition. Try adding 3 to 12, and that gives you the next multiple.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do you calculate 10% of 250? ||| student: I don’t know how to start.",
        "Expert_Human_Tutor": "One strategy is to divide 250 by 10, which will give you 10%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: Can you simplify the fraction 9/12? ||| student: I’m confused.",
        "Expert_Human_Tutor": "Try finding the largest number that divides both 9 and 12 evenly. That’s the greatest common factor.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s 7 squared? ||| student: I don’t understand the process.",
        "Expert_Human_Tutor": "Square means multiplying the number by itself. So try calculating 7 × 7.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do you find the area of a triangle? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Use the formula: (base × height) ÷ 2. Multiply the base and height, then divide by 2.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s 30% of 80? ||| student: I’m not sure where to begin.",
        "Expert_Human_Tutor": "First, find 10% of 80 by dividing by 10. Then multiply that result by 3 to get 30%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can you calculate 1/4 of 60? ||| student: I’m a bit lost.",
        "Expert_Human_Tutor": "Divide 60 by 4 to find one-fourth. Breaking it into parts makes it easier.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do you find 3/5 of 100? ||| student: I don’t know the steps.",
        "Expert_Human_Tutor": "Start by dividing 100 by 5 to get one-fifth, then multiply that result by 3.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s the sum of 45 and 17? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "One way is to add 45 and 10 first, then add the remaining 7. Breaking it down makes it simpler.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do you calculate 75% of 40? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Start by finding 50% of 40, then find 25%. Adding those two parts will give you 75%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s the product of 5 and 8? ||| student: I need help.",
        "Expert_Human_Tutor": "Try using repeated addition as a strategy. Add 5 eight times, or think of it as 8 groups of 5.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do you simplify 10/15? ||| student: I don’t know.",
        "Expert_Human_Tutor": "To simplify, find the largest number that divides both 10 and 15, then divide each by that number.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s the remainder when dividing 28 by 5? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Divide 28 by 5, then check what’s left after the closest multiple of 5.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can you estimate 47 + 28? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "A quick way to estimate is to round each number to the nearest ten. So try 50 + 30.",
        "Peda_Strategies": "provide_strategy"
    }
]

# Convert new entries into a DataFrame
new_df_strategy = pd.DataFrame(new_entries_strategy)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_strategy], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New 'provide_strategy' entries added successfully!")
# Out:
# New 'provide_strategy' entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_strategy' pedagogical strategy
new_entries_strategy = [
    {
        "History": "||| teacher: How do you find 20% of 90? ||| student: I’m confused.",
        "Expert_Human_Tutor": "Start by finding 10% of 90, then double it to get 20%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s the best way to solve 8 × 7? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "If 8 × 5 is easy for you, try that first and then add two more 8s.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: Can you solve 40 divided by 8? ||| student: I’m not sure where to start.",
        "Expert_Human_Tutor": "Try thinking of it as ‘how many groups of 8 are in 40.’",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do you simplify the fraction 10/25? ||| student: I need help.",
        "Expert_Human_Tutor": "Divide the numerator and denominator by the greatest common factor, which is 5 in this case.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s 15 + 25? ||| student: I’m struggling to add it.",
        "Expert_Human_Tutor": "Try breaking it down by adding 10 to 25 first, then add the remaining 5.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can you estimate 47 × 9? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Round 47 to 50, then multiply by 9. Estimation helps make mental math easier.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s a quick way to find 3/4 of 100? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Try finding 1/4 first by dividing 100 by 4, then multiply that by 3.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can you calculate the perimeter of a rectangle? ||| student: I don’t remember the formula.",
        "Expert_Human_Tutor": "For a rectangle, add the lengths of all four sides, or use 2 × (length + width).",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I find the product of 6 and 9? ||| student: I’m a bit lost.",
        "Expert_Human_Tutor": "Try using repeated addition. Think of it as adding 6 nine times or 9 six times.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s a good way to add 18 and 25? ||| student: I don’t know where to start.",
        "Expert_Human_Tutor": "Try rounding each number to the nearest ten, then adjust. So 20 + 30, then subtract 2.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I solve 60% of 150? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Find 50% of 150, then find 10% and add those two parts together to make 60%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do you simplify 24/36? ||| student: I need help.",
        "Expert_Human_Tutor": "Find the largest number that divides evenly into both. Here, divide both by 12 to simplify.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s a quick way to multiply 9 and 8? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "Use the distributive property: think of 9 as 10 - 1, so (10 × 8) - (1 × 8).",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I calculate 4/5 of 50? ||| student: I’m unsure where to start.",
        "Expert_Human_Tutor": "Divide 50 by 5 to get one-fifth, then multiply by 4 to get four-fifths.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s an easy way to find 12 + 15? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Try adding 10 + 10 first, then add the remaining parts (2 and 5). Breaking it down can help.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s 75% of 80? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Start by finding 50% of 80, then find 25%, and add them together to get 75%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I subtract 26 from 50? ||| student: I’m stuck.",
        "Expert_Human_Tutor": "Try subtracting 20 first to get 30, then subtract the remaining 6.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I find the product of 14 and 3? ||| student: I don’t remember the steps.",
        "Expert_Human_Tutor": "Break it into easier parts: multiply 10 by 3, then 4 by 3, and add the results.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I calculate 10% of a number? ||| student: I don’t know.",
        "Expert_Human_Tutor": "A simple way is to move the decimal point one place to the left. That’s 10%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I quickly multiply by 5? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "One trick is to halve the number, then multiply by 10. This makes the calculation faster.",
        "Peda_Strategies": "provide_strategy"
    }
]

# Convert new entries into a DataFrame
new_df_strategy = pd.DataFrame(new_entries_strategy)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_strategy], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New 'provide_strategy' entries added successfully!")
# Out:
# New 'provide_strategy' entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_strategy' pedagogical strategy
new_entries_strategy = [
    {
        "History": "||| teacher: How do you calculate 12% of 50? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "First, find 10% of 50, then find 1% and double it. Add those results to get 12%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s a quick way to find 7 × 8? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "Try thinking of 7 as 5 + 2. Multiply 5 × 8, then add 2 × 8 to get the result.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do you add 35 and 46? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Round 35 up to 40, add it to 46, then subtract the extra 5 you added.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s an easy way to solve 80 ÷ 4? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Divide 80 into two parts, 40 and 40. Divide each by 4, then add them up.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do you simplify 16/24? ||| student: I need help.",
        "Expert_Human_Tutor": "Divide both the numerator and denominator by their greatest common factor, which is 8.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can you find the perimeter of a triangle with sides 6, 7, and 5? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Simply add the lengths of all three sides: 6 + 7 + 5.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s a quick way to find 40% of 90? ||| student: I’m confused.",
        "Expert_Human_Tutor": "First, find 10% of 90, then multiply it by 4 to get 40%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I subtract 19 from 47? ||| student: I don’t know where to begin.",
        "Expert_Human_Tutor": "Try rounding 19 to 20, subtract, and then add 1 back to the result.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s the fastest way to multiply 25 by 4? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Multiply 25 by 2 to get 50, then double it to get the answer.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do you find the sum of 27 and 34? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Try rounding each to the nearest ten, add them, then adjust back for accuracy.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s an easy way to multiply 6 and 12? ||| student: I need help.",
        "Expert_Human_Tutor": "Think of 12 as 10 + 2. Multiply 6 by 10, then 6 by 2, and add the results.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I calculate 9/10 of 80? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "First, find 1/10 by dividing by 10, then multiply by 9 to get 9/10.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s an easy way to find the product of 11 and 5? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Think of it as 10 × 5 + 1 × 5. Add those two parts for the answer.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do you simplify 6/18? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Find the greatest common factor, which is 6. Then divide both by 6 to simplify.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s the perimeter of a square with a side of 6? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Since a square has four equal sides, multiply 6 by 4 to get the perimeter.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I estimate 53 + 48? ||| student: I’m confused.",
        "Expert_Human_Tutor": "Round 53 to 50 and 48 to 50, add them, then adjust slightly to be accurate.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I calculate 75% of 120? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Find 50% of 120, then find 25%, and add those two results to get 75%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s the best way to find 4/5 of 100? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Divide 100 by 5 to find one-fifth, then multiply by 4 to get four-fifths.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I quickly multiply 8 and 12? ||| student: I need help.",
        "Expert_Human_Tutor": "Break it down: think of 8 as 10 - 2, then multiply each part by 12 and subtract.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s an easy way to find 5% of 200? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Find 10% of 200 by dividing by 10, then take half of that to get 5%.",
        "Peda_Strategies": "provide_strategy"
    }
]

# Convert new entries into a DataFrame
new_df_strategy = pd.DataFrame(new_entries_strategy)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_strategy], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New 'provide_strategy' entries added successfully!")
# Out:
# New 'provide_strategy' entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_strategy' pedagogical strategy
new_entries_strategy = [
    {
        "History": "||| teacher: How can you quickly add 57 and 26? ||| student: I don’t know where to start.",
        "Expert_Human_Tutor": "Round 57 to 60, add it to 26, and then subtract the extra 3.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s an easy way to calculate 4/9 of 90? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Start by dividing 90 by 9 to get one-ninth, then multiply by 4.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I find the product of 7 and 12? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Try breaking 12 into 10 + 2. Multiply each part by 7, then add the results.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s a quick way to subtract 28 from 73? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "Try subtracting 30 to get 43, then add 2 back to get the exact answer.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do you find 5% of 250? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Find 10% of 250 by dividing by 10, then take half of that to get 5%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s a good way to multiply 9 and 14? ||| student: I need help.",
        "Expert_Human_Tutor": "Think of 9 as 10 - 1, so you can calculate (10 × 14) - (1 × 14).",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can you calculate 40% of 70? ||| student: I’m not sure where to begin.",
        "Expert_Human_Tutor": "Start by finding 10% of 70, then multiply by 4 to get 40%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s an easy way to find the sum of 68 and 33? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Round 68 to 70, add it to 33, then subtract 2 to get the exact answer.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do you simplify 14/28? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Divide both the numerator and denominator by 14, the greatest common factor.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s a good way to multiply 6 by 15? ||| student: I’m stuck.",
        "Expert_Human_Tutor": "Think of 15 as 10 + 5. Multiply each part by 6 and then add them together.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I estimate 59 + 27? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Round 59 to 60 and 27 to 30, add those, then adjust back slightly for accuracy.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s a fast way to find 3/4 of 80? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Divide 80 by 4 to get one-fourth, then multiply by 3 for three-fourths.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I find 25% of a number quickly? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Divide the number by 4, since 25% is the same as one-fourth.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s the perimeter of a rectangle with sides of 9 and 6? ||| student: I’m confused.",
        "Expert_Human_Tutor": "Add both side lengths and multiply by 2, since you have two of each side.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do you find the product of 8 and 7? ||| student: I need a method.",
        "Expert_Human_Tutor": "Think of 8 as 10 - 2, then multiply each part by 7 and subtract.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s the fastest way to calculate 50% of 180? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Take half of 180, since 50% is the same as dividing by 2.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I quickly subtract 9 from 52? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Subtract 10 first, then add 1 back to get the exact answer.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s a good method for finding 2/3 of 90? ||| student: I don’t know.",
        "Expert_Human_Tutor": "First, divide 90 by 3, then multiply the result by 2.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do you calculate 60% of 150? ||| student: I’m lost.",
        "Expert_Human_Tutor": "Find 50% of 150, then 10%, and add those two together to get 60%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s a quick way to add 38 and 29? ||| student: I’m stuck.",
        "Expert_Human_Tutor": "Round 38 to 40, add it to 29, and then subtract the extra 2.",
        "Peda_Strategies": "provide_strategy"
    }
]

# Convert new entries into a DataFrame
new_df_strategy = pd.DataFrame(new_entries_strategy)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_strategy], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New 'provide_strategy' entries added successfully!")
# Out:
# New 'provide_strategy' entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_hint' pedagogical strategy
new_entries_hint = [
    {
        "History": "||| teacher: How can you quickly add 57 and 26? ||| student: I don’t know where to start.",
        "Expert_Human_Tutor": "Round 57 to 60, add it to 26, and then subtract the extra 3.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s an easy way to calculate 4/9 of 90? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Start by dividing 90 by 9 to get one-ninth, then multiply by 4.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How can I find the product of 7 and 12? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Try breaking 12 into 10 + 2. Multiply each part by 7, then add the results.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s a quick way to subtract 28 from 73? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "Try subtracting 30 to get 43, then add 2 back to get the exact answer.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do you find 5% of 250? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Find 10% of 250 by dividing by 10, then take half of that to get 5%.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s a good way to multiply 9 and 14? ||| student: I need help.",
        "Expert_Human_Tutor": "Think of 9 as 10 - 1, so you can calculate (10 × 14) - (1 × 14).",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How can you calculate 40% of 70? ||| student: I’m not sure where to begin.",
        "Expert_Human_Tutor": "Start by finding 10% of 70, then multiply by 4 to get 40%.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s an easy way to find the sum of 68 and 33? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Round 68 to 70, add it to 33, then subtract 2 to get the exact answer.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do you simplify 14/28? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Divide both the numerator and denominator by 14, the greatest common factor.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s a good way to multiply 6 by 15? ||| student: I’m stuck.",
        "Expert_Human_Tutor": "Think of 15 as 10 + 5. Multiply each part by 6 and then add them together.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How can I estimate 59 + 27? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Round 59 to 60 and 27 to 30, add those, then adjust back slightly for accuracy.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s a fast way to find 3/4 of 80? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Divide 80 by 4 to get one-fourth, then multiply by 3 for three-fourths.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I find 25% of a number quickly? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Divide the number by 4, since 25% is the same as one-fourth.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the perimeter of a rectangle with sides of 9 and 6? ||| student: I’m confused.",
        "Expert_Human_Tutor": "Add both side lengths and multiply by 2, since you have two of each side.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do you find the product of 8 and 7? ||| student: I need a method.",
        "Expert_Human_Tutor": "Think of 8 as 10 - 2, then multiply each part by 7 and subtract.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the fastest way to calculate 50% of 180? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Take half of 180, since 50% is the same as dividing by 2.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How can I quickly subtract 9 from 52? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Subtract 10 first, then add 1 back to get the exact answer.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s a good method for finding 2/3 of 90? ||| student: I don’t know.",
        "Expert_Human_Tutor": "First, divide 90 by 3, then multiply the result by 2.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do you calculate 60% of 150? ||| student: I’m lost.",
        "Expert_Human_Tutor": "Find 50% of 150, then 10%, and add those two together to get 60%.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s a quick way to add 38 and 29? ||| student: I’m stuck.",
        "Expert_Human_Tutor": "Round 38 to 40, add it to 29, and then subtract the extra 2.",
        "Peda_Strategies": "provide_hint"
    }
]

# Convert new entries into a DataFrame
new_df_hint = pd.DataFrame(new_entries_hint)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_hint], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New 'provide_hint' entries added successfully!")
# Out:
# New 'provide_hint' entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_hint' pedagogical strategy
new_entries_hint = [
    {
        "History": "||| teacher: How do you find 2/5 of 50? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Try dividing 50 by 5 first to find one-fifth, then multiply by 2.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s 10% of 150? ||| student: I’m a bit lost.",
        "Expert_Human_Tutor": "To find 10%, just move the decimal one place to the left.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do you simplify 9/18? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Think of the largest number that divides both 9 and 18 evenly.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the square of 5? ||| student: I forgot.",
        "Expert_Human_Tutor": "Remember that squaring a number means multiplying it by itself.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How can I calculate 1/3 of 21? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "Try dividing 21 by 3 to find one-third.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s 45% of 200? ||| student: I don’t know.",
        "Expert_Human_Tutor": "First, find 50% of 200, then find 5%, and subtract that from 50%.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do you add 49 and 38? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Try rounding each number to the nearest ten, then add, and adjust.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the product of 6 and 9? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Think of 6 as 5 + 1 and then multiply each part by 9.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How can I find 20% of 300? ||| student: I’m stuck.",
        "Expert_Human_Tutor": "Start by finding 10% of 300, then double it for 20%.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I simplify 10/30? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Look for the largest number that can divide both 10 and 30.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s 12 times 4? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Think of 12 as 10 + 2, then multiply each by 4 and add the results.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I calculate 4/5 of 100? ||| student: I need help.",
        "Expert_Human_Tutor": "Divide 100 by 5 to find one-fifth, then multiply by 4.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s 75% of 60? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "Find 50% of 60, then find 25% and add those together.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I find 3/8 of 40? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Try dividing 40 by 8 to find one-eighth, then multiply by 3.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the next multiple of 4 after 20? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Try adding 4 to 20 to find the next multiple.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do you calculate the area of a square with side length 5? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Remember, the area of a square is side × side.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s 15% of 80? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Start by finding 10% of 80, then find 5% and add them together.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I calculate 40% of 250? ||| student: I’m stuck.",
        "Expert_Human_Tutor": "Find 10% of 250, then multiply that result by 4.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s a quick way to subtract 8 from 52? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Try subtracting 10 first, then add 2 back to the result.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How can I find the product of 7 and 8? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "Think of 7 as 5 + 2 and then multiply each part by 8.",
        "Peda_Strategies": "provide_hint"
    }
]

# Convert new entries into a DataFrame
new_df_hint = pd.DataFrame(new_entries_hint)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_hint], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New 'provide_hint' entries added successfully!")
# Out:
# New 'provide_hint' entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_hint' pedagogical strategy
new_entries_hint = [
    {
        "History": "||| teacher: How do you calculate 15% of 200? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Start by finding 10% of 200, then find 5% and add them together.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the product of 4 and 11? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "Think of 11 as 10 + 1, then multiply each part by 4 and add the results.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do you simplify 18/24? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Look for the largest number that divides both 18 and 24 evenly.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the square root of 49? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Think of a number that, when multiplied by itself, gives 49.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How can you find 5/6 of 60? ||| student: I’m not sure where to start.",
        "Expert_Human_Tutor": "Divide 60 by 6 to find one-sixth, then multiply by 5.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s 50% of 120? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Remember, 50% is the same as dividing by 2.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do you calculate the perimeter of a rectangle with length 8 and width 3? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Add the lengths of all four sides, or use 2 × (length + width).",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do you find 3/4 of 100? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Divide 100 by 4 to get one-fourth, then multiply by 3 for three-fourths.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the next multiple of 6 after 24? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Try adding 6 to 24 to find the next multiple.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I add 63 and 29? ||| student: I’m struggling with it.",
        "Expert_Human_Tutor": "Round each number to the nearest ten, add them, then adjust slightly.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the best way to multiply 9 by 13? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Think of 13 as 10 + 3, multiply each part by 9, then add the results.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How can I calculate 30% of 150? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Find 10% of 150, then multiply it by 3 to get 30%.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s 25% of 60? ||| student: I don’t know where to start.",
        "Expert_Human_Tutor": "Remember, 25% is the same as dividing by 4.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do you find the square of 12? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Squaring means multiplying the number by itself. Try 12 × 12.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do you calculate 2/3 of 90? ||| student: I need help.",
        "Expert_Human_Tutor": "Start by dividing 90 by 3 to find one-third, then multiply by 2.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the sum of 47 and 68? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Try rounding each number to the nearest ten, add, then adjust for accuracy.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do you simplify 15/35? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Look for the largest number that divides both 15 and 35 evenly.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How can you estimate 52 + 39? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "Round 52 to 50 and 39 to 40, then add for an approximate answer.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s a quick way to calculate 5 × 14? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Think of 14 as 10 + 4, then multiply each part by 5 and add the results.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I find 40% of 250? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Find 10% of 250, then multiply by 4 to get 40%.",
        "Peda_Strategies": "provide_hint"
    }
]

# Convert new entries into a DataFrame
new_df_hint = pd.DataFrame(new_entries_hint)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_hint], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New 'provide_hint' entries added successfully!")
# Out:
# New 'provide_hint' entries added successfully!

# %%
import pandas as pd

# Load the existing dataset
file_path = '/content/reduced_dataset.csv'  # Update the file path if needed
df = pd.read_csv(file_path)

# New entries to be added with 'provide_hint' pedagogical strategy
new_entries_hint = [
    {
        "History": "||| teacher: How do I find 7% of 200? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Try finding 1% first by dividing by 100, then multiply that by 7.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s 3/5 of 45? ||| student: I don’t know how to start.",
        "Expert_Human_Tutor": "Divide 45 by 5 to find one-fifth, then multiply by 3 to get three-fifths.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How can I simplify 20/50? ||| student: I’m stuck.",
        "Expert_Human_Tutor": "Look for the largest number that can divide both 20 and 50 evenly.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s 9 squared? ||| student: I can’t remember.",
        "Expert_Human_Tutor": "Square means multiplying the number by itself. Try 9 × 9.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do you calculate 12% of 250? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Start by finding 10% of 250, then find 1% and double it.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s a fast way to add 73 and 27? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Try rounding 73 to 70 and 27 to 30, then add and adjust.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I calculate the product of 6 and 15? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Think of 15 as 10 + 5, multiply each by 6, then add the results.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s an easy way to find 8 times 13? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Think of 13 as 10 + 3, then multiply each part by 8 and add them up.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do you find 3/4 of 60? ||| student: I don’t know where to begin.",
        "Expert_Human_Tutor": "Divide 60 by 4 to get one-fourth, then multiply that by 3.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the next multiple of 7 after 28? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Try adding 7 to 28 to get the next multiple.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How can I quickly subtract 19 from 42? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "Try rounding 19 to 20, subtract that, and add 1 back.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I calculate 25% of 90? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Remember that 25% is one-fourth, so divide 90 by 4.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the perimeter of a rectangle with length 10 and width 7? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Use the formula 2 × (length + width) to find the perimeter.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How can I simplify 10/40? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Look for the greatest common factor. In this case, divide both by 10.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the square root of 64? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Think of a number that, when multiplied by itself, equals 64.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do you calculate 5% of 150? ||| student: I’m lost.",
        "Expert_Human_Tutor": "Start by finding 10% of 150, then divide that in half to get 5%.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the sum of 58 and 36? ||| student: I need help.",
        "Expert_Human_Tutor": "Round each number to the nearest ten, add them, then adjust for accuracy.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I find 2/3 of 45? ||| student: I don’t know where to start.",
        "Expert_Human_Tutor": "Divide 45 by 3 to find one-third, then multiply that by 2.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s a good way to multiply 4 by 17? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Think of 17 as 10 + 7, then multiply each part by 4 and add the results.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do you calculate 10% of a number quickly? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Just move the decimal one place to the left to find 10%.",
        "Peda_Strategies": "provide_hint"
    }
]

# Convert new entries into a DataFrame
new_df_hint = pd.DataFrame(new_entries_hint)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_hint], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New 'provide_hint' entries added successfully!")
# Out:
# New 'provide_hint' entries added successfully!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('/content/reduced_dataset.csv')  # Replace 'your_dataset.csv' with the path to your dataset

# Count occurrences of each pedagogical strategy
strategy_counts = data['Peda_Strategies'].value_counts()

# Plot the strategy counts as a bar chart
plt.figure(figsize=(10, 6))
strategy_counts.plot(kind='bar')
plt.title('Count of Each Pedagogical Strategy')
plt.xlabel('Pedagogical Strategy')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

plt.savefig('pedagogical_strategy_counts.png', dpi=300, bbox_inches='tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load both datasets
data1 = pd.read_csv('/content/reduced_dataset.csv')  # Path to the first dataset
data2 = pd.read_csv('/content/reduced_dataset (GPT-4o).csv')  # Path to the second dataset (update the path as needed)

# Count occurrences of each pedagogical strategy in both datasets
strategy_counts1 = data1['Peda_Strategies'].value_counts()
strategy_counts2 = data2['Peda_Strategies'].value_counts()

# Combine the counts into a DataFrame for easier plotting
comparison_df = pd.DataFrame({
    'Original Dataset': strategy_counts1,
    'Augmented (GPT-4o) Dataset': strategy_counts2
}).fillna(0)  # Fill any missing values with 0

# Plot the comparison as a bar chart
comparison_df.plot(kind='bar', figsize=(12, 7))
plt.title('Comparison of Pedagogical Strategy Counts in Two Datasets')
plt.xlabel('Pedagogical Strategy')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Save the comparison chart as an image file
plt.savefig('pedagogical_strategy_comparison.png', dpi=300, bbox_inches='tight')

# Display the chart
plt.show()

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('/content/reduced_dataset (GPT-4o).csv')  # Replace 'your_dataset.csv' with the path to your dataset

# Shuffle the rows
shuffled_data = data.sample(frac=1, random_state=42).reset_index(drop=True)

# Save the shuffled dataset to a new file
shuffled_data.to_csv('shuffled_dataset.csv', index=False)

print("Dataset rows have been shuffled and saved as 'shuffled_dataset.csv'")
# Out:
# Dataset rows have been shuffled and saved as 'shuffled_dataset.csv'

# %%
import pandas as pd

# Path to your existing CSV file
file_path = '/content/shuffled_reduced_dataset (GPT-4o).csv'  # Update with the correct file path
df = pd.read_csv(file_path)  # Load the existing dataset into a pandas DataFrame

# New entries for the "explain_concept" strategy
new_entries_explain_concept = [
    {
        "History": "||| teacher: What does 'perimeter' mean? ||| student: Is it the same as area?",
        "Expert_Human_Tutor": "The perimeter is the total length around a shape, like adding up all the side lengths of a rectangle.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What is a fraction? ||| student: Is it just a small number?",
        "Expert_Human_Tutor": "A fraction represents a part of a whole, like cutting a pizza into slices and taking some of them.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Can you explain 'average'? ||| student: Is it the same as total?",
        "Expert_Human_Tutor": "Average is like finding the middle value by adding all numbers and dividing by how many numbers you added.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What does it mean to 'simplify' a fraction? ||| student: Does it change the fraction?",
        "Expert_Human_Tutor": "Simplifying a fraction means making it as simple as possible without changing its value.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What’s a 'decimal'? ||| student: Is it just a dot?",
        "Expert_Human_Tutor": "A decimal is a way to show parts of a whole using place value, like 0.5 represents half.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Can you explain what a 'multiple' is? ||| student: Is it like addition?",
        "Expert_Human_Tutor": "A multiple of a number is the result you get when you multiply that number by an integer.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What does 'product' mean in math? ||| student: Is it like multiplication?",
        "Expert_Human_Tutor": "Yes, the product is the answer you get when you multiply two numbers together.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What is an 'exponent'? ||| student: Is it just a small number?",
        "Expert_Human_Tutor": "An exponent shows how many times a number is multiplied by itself. For example, 2^3 means 2 × 2 × 2.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Can you explain what 'radius' means? ||| student: Is it a line?",
        "Expert_Human_Tutor": "The radius is a line from the center of a circle to any point on its edge.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What is the 'mean' in a set of numbers? ||| student: Is it the most common number?",
        "Expert_Human_Tutor": "The mean is the average; you add all the numbers and divide by how many there are.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What does 'volume' mean? ||| student: Is it the same as area?",
        "Expert_Human_Tutor": "Volume measures how much space an object occupies, like how much liquid fits inside a bottle.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What is a 'factor'? ||| student: Is it a part of a number?",
        "Expert_Human_Tutor": "A factor is a number that divides another number without leaving a remainder, like 3 is a factor of 9.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Can you explain 'median' in statistics? ||| student: Is it like the average?",
        "Expert_Human_Tutor": "The median is the middle value in a list of numbers arranged from smallest to largest.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What does 'perpendicular' mean? ||| student: Is it just two lines crossing?",
        "Expert_Human_Tutor": "Perpendicular lines meet to form a right angle, exactly 90 degrees.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Can you explain what a 'denominator' is? ||| student: Is it the bottom of a fraction?",
        "Expert_Human_Tutor": "Yes, the denominator is the bottom number in a fraction, showing how many parts make a whole.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What does 'acute angle' mean? ||| student: Is it any angle?",
        "Expert_Human_Tutor": "An acute angle is any angle less than 90 degrees, smaller than a right angle.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What’s an 'equation'? ||| student: Is it like an expression?",
        "Expert_Human_Tutor": "An equation has an equal sign, showing that two expressions are equal.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Can you explain 'equivalent fractions'? ||| student: Are they the same as normal fractions?",
        "Expert_Human_Tutor": "Equivalent fractions have the same value but look different, like 1/2 and 2/4.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What does 'divisor' mean? ||| student: Is it the number you divide by?",
        "Expert_Human_Tutor": "Yes, the divisor is the number you use to divide another number.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What is 'area'? ||| student: Is it the same as perimeter?",
        "Expert_Human_Tutor": "The area is the amount of space inside a shape, like how much surface is inside a rectangle.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Can you explain what a 'prime number' is? ||| student: Is it any number?",
        "Expert_Human_Tutor": "A prime number has only two factors: 1 and itself, like 3 or 5.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What does 'remainder' mean in division? ||| student: Is it an extra number?",
        "Expert_Human_Tutor": "Yes, a remainder is what's left over when one number doesn't divide another evenly.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What is a 'polygon'? ||| student: Is it any shape?",
        "Expert_Human_Tutor": "A polygon is a closed shape with straight sides, like a triangle or square.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What does 'estimate' mean in math? ||| student: Is it a guess?",
        "Expert_Human_Tutor": "Estimation gives an approximate answer, close to the exact value.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Can you explain 'parallel lines'? ||| student: Are they just two lines?",
        "Expert_Human_Tutor": "Parallel lines never meet; they stay the same distance apart.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What does 'hypotenuse' mean in a triangle? ||| student: Is it a side?",
        "Expert_Human_Tutor": "The hypotenuse is the longest side of a right triangle, opposite the right angle.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What is a 'percent'? ||| student: Is it a part of something?",
        "Expert_Human_Tutor": "A percent is a part of 100, like 25% means 25 out of 100.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Can you explain 'decimal place'? ||| student: Is it part of a decimal?",
        "Expert_Human_Tutor": "Yes, each place after the decimal point shows tenths, hundredths, etc., getting smaller.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What does 'numerator' mean? ||| student: Is it the top number in a fraction?",
        "Expert_Human_Tutor": "Correct, the numerator is the top part, showing how many parts we have.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What is a 'right angle'? ||| student: Is it any angle?",
        "Expert_Human_Tutor": "A right angle is exactly 90 degrees, forming a perfect corner.",
        "Peda_Strategies": "explain_concept"
    }
]

# Convert new entries into a DataFrame
new_df_explain_concept = pd.DataFrame(new_entries_explain_concept)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_explain_concept], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("New 'explain_concept' entries added successfully!")
# Out:
# New 'explain_concept' entries added successfully!

# %%
import pandas as pd

# Path to your existing CSV file
file_path = '/content/shuffled_reduced_dataset (GPT-4o).csv'  # Update with the correct file path
df = pd.read_csv(file_path)  # Load the existing dataset into a pandas DataFrame

# New entries for the "explain_concept" strategy (10 additional examples)
new_entries_explain_concept_10 = [
    {
        "History": "||| teacher: What does 'difference' mean in math? ||| student: Is it like the answer in addition?",
        "Expert_Human_Tutor": "The difference is the answer you get when you subtract one number from another.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What is a 'ratio'? ||| student: Is it the same as a fraction?",
        "Expert_Human_Tutor": "A ratio compares two quantities, like saying for every 2 apples, there are 3 oranges.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Can you explain what 'percent increase' means? ||| student: Does it mean just adding percent?",
        "Expert_Human_Tutor": "Percent increase shows how much something grows as a percentage of the original amount.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What does 'symmetry' mean? ||| student: Is it like two matching parts?",
        "Expert_Human_Tutor": "Yes, symmetry means one part is a mirror image of the other.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Can you explain 'mean' in math? ||| student: Is it just an average?",
        "Expert_Human_Tutor": "Yes, the mean is the average. Add all numbers together and divide by the count of numbers.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What does 'axis' mean on a graph? ||| student: Is it just a line?",
        "Expert_Human_Tutor": "The axis is a reference line on a graph. The x-axis runs horizontally, and the y-axis runs vertically.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What is a 'quadrilateral'? ||| student: Is it a type of shape?",
        "Expert_Human_Tutor": "A quadrilateral is a shape with four straight sides, like a rectangle or square.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: Can you explain 'divisible'? ||| student: Is it about division?",
        "Expert_Human_Tutor": "Yes, a number is divisible by another if it can be divided without leaving a remainder.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What does 'circumference' mean? ||| student: Is it like a perimeter for circles?",
        "Expert_Human_Tutor": "Exactly! The circumference is the distance around the edge of a circle.",
        "Peda_Strategies": "explain_concept"
    },
    {
        "History": "||| teacher: What is a 'composite number'? ||| student: Is it similar to a prime number?",
        "Expert_Human_Tutor": "A composite number has more than two factors, meaning it can be divided by numbers other than 1 and itself.",
        "Peda_Strategies": "explain_concept"
    }
]

# Convert new entries into a DataFrame
new_df_explain_concept_10 = pd.DataFrame(new_entries_explain_concept_10)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_explain_concept_10], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("10 new 'explain_concept' entries added successfully!")
# Out:
# 10 new 'explain_concept' entries added successfully!

# %%
import pandas as pd

# Path to your existing CSV file
file_path = '/content/shuffled_reduced_dataset (GPT-4o).csv'  # Update with the correct file path
df = pd.read_csv(file_path)  # Load the existing dataset into a pandas DataFrame

# New entries for the "provide_hint" strategy (20 new examples)
new_entries_provide_hint_20 = [
    {
        "History": "||| teacher: What is 12 + 15? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Try adding 10 to 15 first, then add the remaining 2.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I find 4/5 of 25? ||| student: I don’t know where to start.",
        "Expert_Human_Tutor": "First, divide 25 by 5 to find one-fifth, then multiply that by 4.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the next multiple of 3 after 27? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Try adding 3 to 27 to get the next multiple.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I simplify 6/18? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Look for the largest number that divides both 6 and 18 evenly.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What is 25% of 80? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Remember, 25% is the same as one-fourth. Try dividing 80 by 4.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s 10% of 300? ||| student: I don’t know how to do that.",
        "Expert_Human_Tutor": "Move the decimal one place to the left to find 10%.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How can I add 64 and 37? ||| student: I’m having trouble.",
        "Expert_Human_Tutor": "Try rounding 64 to 60 and 37 to 40, then add and adjust.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I find 1/6 of 30? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Divide 30 by 6 to find one-sixth.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the square of 8? ||| student: I’m stuck.",
        "Expert_Human_Tutor": "Remember that squaring a number means multiplying it by itself.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What is 50% of 90? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Since 50% is half, try dividing 90 by 2.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I calculate 3/8 of 40? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Divide 40 by 8 to get one-eighth, then multiply by 3.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the difference between 75 and 28? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "Try subtracting 30 from 75, then add 2 to your answer.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I add 47 and 36? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Round each number to the nearest ten, add them, then adjust for accuracy.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s 20% of 250? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Try finding 10% of 250 first, then double it to get 20%.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s 3/4 of 80? ||| student: I’m stuck.",
        "Expert_Human_Tutor": "Divide 80 by 4 to find one-fourth, then multiply by 3.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I calculate 7% of 100? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Find 1% by dividing by 100, then multiply by 7.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the next multiple of 5 after 45? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Add 5 to 45 to find the next multiple.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What is 75% of 120? ||| student: I’m not sure where to start.",
        "Expert_Human_Tutor": "Try finding 50% of 120, then find 25%, and add them together.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I subtract 18 from 53? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Try subtracting 20 from 53, then add 2 to the result.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What is 15% of 80? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "Start by finding 10% of 80, then find 5% and add them together.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I calculate 6 times 15? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Think of 15 as 10 + 5, then multiply each part by 6 and add.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the square root of 36? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Think of a number that, when multiplied by itself, gives 36.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I find 4/7 of 35? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Divide 35 by 7 to get one-seventh, then multiply by 4.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s an easy way to add 56 and 29? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "Round each number to the nearest ten, add them, then adjust.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I calculate 12% of 400? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Start by finding 10% of 400, then find 1% and double it to get 12%.",
        "Peda_Strategies": "provide_hint"
    }
]

# Convert new entries into a DataFrame
new_df_provide_hint_20 = pd.DataFrame(new_entries_provide_hint_20)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_provide_hint_20], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("20 new 'provide_hint' entries added successfully!")
# Out:
# 20 new 'provide_hint' entries added successfully!

# %%
import pandas as pd

# Path to your existing CSV file
file_path = '/content/shuffled_reduced_dataset (GPT-4o).csv'  # Update with the correct file path

# Load the existing dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# New entries for the "provide_hint" strategy (25 new examples)
new_entries_provide_hint_25 = [
    {
        "History": "||| teacher: What is 8 + 17? ||| student: I’m not sure how to start.",
        "Expert_Human_Tutor": "Try adding 10 to 17 first, then add the remaining 8.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I find 5/6 of 18? ||| student: I don’t know where to start.",
        "Expert_Human_Tutor": "First, divide 18 by 6 to get one-sixth, then multiply that by 5.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the next multiple of 4 after 32? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Add 4 to 32 to find the next multiple.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I simplify 10/25? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Look for the largest number that divides both 10 and 25 evenly.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What is 10% of 150? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Move the decimal one place to the left to find 10%.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s 1/2 of 75? ||| student: I don’t know how to calculate that.",
        "Expert_Human_Tutor": "Remember that 1/2 means dividing by 2, so divide 75 by 2.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I calculate 3/7 of 42? ||| student: I’m having trouble.",
        "Expert_Human_Tutor": "Divide 42 by 7 to find one-seventh, then multiply by 3.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the square of 7? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Squaring a number means multiplying it by itself. Try 7 × 7.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the square root of 81? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Think of a number that, when multiplied by itself, equals 81.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I find 2/3 of 90? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Start by dividing 90 by 3 to find one-third, then multiply by 2.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the product of 5 and 18? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Think of 18 as 10 + 8, then multiply each part by 5 and add.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I calculate 20% of 250? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Try finding 10% first by dividing by 10, then double that to get 20%.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s 50% of 120? ||| student: I don’t know how to start.",
        "Expert_Human_Tutor": "Remember, 50% means half, so try dividing 120 by 2.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I find 3/5 of 75? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "First, divide 75 by 5 to get one-fifth, then multiply by 3.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the next multiple of 6 after 42? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Add 6 to 42 to get the next multiple.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How can I add 67 and 25? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Round 67 to 70, add 25, and then subtract 3 for accuracy.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I calculate 25% of 200? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Remember that 25% is the same as dividing by 4, so try dividing 200 by 4.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the product of 9 and 14? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Think of 9 as 10 - 1, then multiply each part by 14 and subtract.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What is 75% of 80? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Find 50% of 80 first, then find 25%, and add them together.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How can I simplify 14/28? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "Find the largest number that divides both 14 and 28 evenly.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I find 10% of 360? ||| student: I don’t know.",
        "Expert_Human_Tutor": "To find 10%, just move the decimal one place to the left.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s 4/5 of 45? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "First, divide 45 by 5 to get one-fifth, then multiply by 4.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: How do I calculate 7% of 400? ||| student: I don’t know where to start.",
        "Expert_Human_Tutor": "Find 1% by dividing by 100, then multiply by 7.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s the difference between 62 and 28? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Try subtracting 30 from 62, then add 2 to the answer.",
        "Peda_Strategies": "provide_hint"
    },
    {
        "History": "||| teacher: What’s an easy way to multiply 6 by 15? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Think of 15 as 10 + 5, then multiply each part by 6 and add the results.",
        "Peda_Strategies": "provide_hint"
    }
]

# Convert new entries into a DataFrame
new_df_provide_hint_25 = pd.DataFrame(new_entries_provide_hint_25)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_provide_hint_25], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("25 new 'provide_hint' entries added successfully!")
# Out:
# 25 new 'provide_hint' entries added successfully!

# %%
import pandas as pd

# Path to your existing CSV file
file_path = '/content/shuffled_reduced_dataset (GPT-4o).csv'  # Update with the correct file path

# Load the existing dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# New entries for the "provide_strategy" strategy (30 new examples)
new_entries_provide_strategy_30 = [
    {
        "History": "||| teacher: What’s 45% of 200? ||| student: I’m not sure how to find that.",
        "Expert_Human_Tutor": "Try finding 50% of 200 first, then subtract 5% to get 45%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I solve 3x = 12? ||| student: I’m stuck.",
        "Expert_Human_Tutor": "To isolate x, try dividing both sides by 3.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s the best way to add 67 and 29? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "One strategy is to round each number to the nearest ten, add, then adjust.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I find 75% of 80? ||| student: I don’t know where to begin.",
        "Expert_Human_Tutor": "Start by finding 50% of 80, then add 25% of 80 to get 75%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s the product of 7 and 15? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Think of 15 as 10 + 5, then multiply each part by 7 and add the results.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I subtract 24 from 56? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Try breaking 24 into 20 + 4, subtract 20, then subtract 4.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s a quick way to multiply 6 by 16? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Break 16 into 10 + 6, multiply each part by 6, then add the results.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I solve for y in 4y = 20? ||| student: I’m confused.",
        "Expert_Human_Tutor": "Isolate y by dividing both sides by 4.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s an easy way to find 60% of 300? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "First, find 50% of 300, then add 10% of 300.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I calculate 40% of 70? ||| student: I don’t know where to begin.",
        "Expert_Human_Tutor": "Start by finding 10% of 70, then multiply that by 4 to get 40%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s the best way to add 43 and 58? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Try rounding each number to the nearest ten, add, then adjust.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I find 3/4 of 120? ||| student: I’m not sure how to do that.",
        "Expert_Human_Tutor": "Start by dividing 120 by 4 to find one-fourth, then multiply by 3.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s 25% of 80? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Since 25% is one-fourth, divide 80 by 4 to get the answer.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I solve for x in 2x + 5 = 15? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "First, subtract 5 from both sides, then divide by 2.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s the best way to multiply 8 and 13? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "Think of 13 as 10 + 3, multiply each part by 8, then add the results.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I calculate 1/5 of 150? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Divide 150 by 5 to find one-fifth of the number.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s 80% of 120? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "First, find 50% of 120, then 30%, and add them together.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I find 3/8 of 64? ||| student: I’m not sure where to start.",
        "Expert_Human_Tutor": "Divide 64 by 8 to find one-eighth, then multiply by 3.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s a good way to subtract 19 from 47? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Round 19 to 20, subtract that, then add 1 back to your answer.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I calculate 4/5 of 60? ||| student: I don’t know.",
        "Expert_Human_Tutor": "First, find one-fifth by dividing 60 by 5, then multiply by 4.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I find the product of 11 and 6? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Break 11 into 10 + 1, then multiply each part by 6 and add the results.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s 15% of 200? ||| student: I’m confused.",
        "Expert_Human_Tutor": "Find 10% first, then find 5%, and add them together to get 15%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I estimate 52 + 38? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Round 52 to 50 and 38 to 40, add them, then adjust slightly.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s 9 × 13? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "Think of 13 as 10 + 3. Multiply each by 9, then add.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I calculate 12% of 250? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Find 10% first, then find 2%, and add them together.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s a quick way to add 56 and 49? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Round 56 to 60 and 49 to 50, add, then adjust slightly.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I multiply 7 by 14 easily? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Think of 14 as 10 + 4, then multiply each part by 7 and add.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I find 60% of 90? ||| student: I’m not sure where to start.",
        "Expert_Human_Tutor": "Find 50% first, then find 10%, and add them to get 60%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s 30% of 200? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Find 10% of 200, then multiply that by 3 to get 30%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I find 2/7 of 56? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Divide 56 by 7 to get one-seventh, then multiply by 2.",
        "Peda_Strategies": "provide_strategy"
    }
]

# Convert new entries into a DataFrame
new_df_provide_strategy_30 = pd.DataFrame(new_entries_provide_strategy_30)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_provide_strategy_30], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("30 new 'provide_strategy' entries added successfully!")
# Out:
# 30 new 'provide_strategy' entries added successfully!

# %%
import pandas as pd

# Path to your existing CSV file
file_path = '/content/shuffled_reduced_dataset (GPT-4o).csv'  # Update with the correct file path

# Load the existing dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# New entries for the "provide_strategy" strategy (30 new examples)
new_entries_provide_strategy_30 = [
    {
        "History": "||| teacher: How can I calculate 45% of 300? ||| student: I’m stuck.",
        "Expert_Human_Tutor": "Try finding 50% of 300, then subtract 5% to get 45%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s a good way to find the product of 8 and 13? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Think of 13 as 10 + 3, multiply each part by 8, then add the results.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I solve 2x + 6 = 18? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Start by subtracting 6 from both sides, then divide by 2.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s 3/5 of 45? ||| student: I don’t remember how.",
        "Expert_Human_Tutor": "First, divide 45 by 5 to find one-fifth, then multiply by 3.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I calculate 6 × 14? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Break 14 into 10 + 4, multiply each part by 6, then add the results.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s the best way to subtract 28 from 73? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Try subtracting 30, then add 2 back to your answer.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I find 1/3 of 60? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Divide 60 by 3 to get one-third of it.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s 25% of 60? ||| student: I’m struggling.",
        "Expert_Human_Tutor": "Since 25% is the same as one-fourth, try dividing 60 by 4.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I find 2/5 of 75? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Start by dividing 75 by 5 to find one-fifth, then multiply by 2.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s an easy way to add 67 and 42? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Try rounding 67 to 70, add, and then adjust by subtracting 3.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I find the product of 5 and 16? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Think of 16 as 10 + 6, then multiply each part by 5 and add them.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I calculate 15% of 300? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Find 10% first, then find 5%, and add them together to get 15%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s 9 × 12? ||| student: I’m stuck.",
        "Expert_Human_Tutor": "Think of 12 as 10 + 2, multiply each part by 9, then add.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I calculate 60% of 150? ||| student: I don’t know where to start.",
        "Expert_Human_Tutor": "First, find 50%, then find 10%, and add them together to make 60%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I solve 4y = 32? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Try dividing both sides by 4 to isolate y.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s a quick way to multiply 7 by 11? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Think of 11 as 10 + 1, then multiply each part by 7 and add.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I find 35% of 100? ||| student: I don’t know where to start.",
        "Expert_Human_Tutor": "Find 10% first, multiply that by 3, then add 5%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s the best way to calculate 4/7 of 70? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Divide 70 by 7 to find one-seventh, then multiply by 4.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I find the square of 15? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Square means multiplying a number by itself, so calculate 15 × 15.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I solve 5x = 40? ||| student: I’m confused.",
        "Expert_Human_Tutor": "To isolate x, divide both sides by 5.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I calculate 12% of 400? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Find 10% of 400, then find 2% and add them.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s a good way to multiply 6 and 14? ||| student: I don’t know how.",
        "Expert_Human_Tutor": "Break 14 into 10 + 4, multiply each by 6, and add the results.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I find 5% of 200? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "Start by finding 10% of 200, then divide that in half to get 5%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s the next multiple of 6 after 36? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Add 6 to 36 to get the next multiple.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I solve for x in x + 7 = 15? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Subtract 7 from both sides to isolate x.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s a good way to add 55 and 48? ||| student: I don’t know.",
        "Expert_Human_Tutor": "Try rounding 55 to 50 and 48 to 50, then add, and adjust for accuracy.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How do I find the product of 7 and 18? ||| student: I don’t remember.",
        "Expert_Human_Tutor": "Think of 18 as 10 + 8, then multiply each by 7, then add.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I calculate 80% of 120? ||| student: I’m unsure.",
        "Expert_Human_Tutor": "First, find 50%, then add 30% to get 80%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: What’s an easy way to find 30% of 250? ||| student: I’m stuck.",
        "Expert_Human_Tutor": "Start by finding 10%, then multiply that by 3 to get 30%.",
        "Peda_Strategies": "provide_strategy"
    },
    {
        "History": "||| teacher: How can I find 3/8 of 80? ||| student: I’m not sure.",
        "Expert_Human_Tutor": "Divide 80 by 8 to get one-eighth, then multiply by 3.",
        "Peda_Strategies": "provide_strategy"
    }
]

# Convert new entries into a DataFrame
new_df_provide_strategy_30 = pd.DataFrame(new_entries_provide_strategy_30)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_provide_strategy_30], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("30 new 'provide_strategy' entries added successfully!")
# Out:
# 30 new 'provide_strategy' entries added successfully!

# %%
import pandas as pd

# Path to your existing CSV file
file_path = '/content/shuffled_reduced_dataset (GPT-4o).csv'  # Update with the correct file path

# Load the existing dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# New entries for the "provide_correction" strategy (36 new examples)
new_entries_provide_correction_36 = [
    {
        "History": "||| teacher: What is 9 times 4? ||| student: 32 ||| teacher: Almost.",
        "Expert_Human_Tutor": "Actually, 9 times 4 is 36, not 32.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the sum of 25 and 17? ||| student: 42 ||| teacher: Close!",
        "Expert_Human_Tutor": "The correct answer is 25 plus 17 equals 42.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 10% of 90? ||| student: 5 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "10% of 90 is 9, not 5.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: How much is 6 squared? ||| student: 12 ||| teacher: Close.",
        "Expert_Human_Tutor": "6 squared is 36, not 12.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: Can you simplify 10/25? ||| student: 1/4 ||| teacher: Almost.",
        "Expert_Human_Tutor": "10/25 simplifies to 2/5, not 1/4.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 7 plus 8? ||| student: 14 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "7 plus 8 equals 15.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is 3 cubed? ||| student: 6 ||| teacher: Close!",
        "Expert_Human_Tutor": "3 cubed is 27, not 6.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 40% of 150? ||| student: 70 ||| teacher: Almost.",
        "Expert_Human_Tutor": "40% of 150 is 60, not 70.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the product of 5 and 9? ||| student: 45 ||| teacher: Yes, that’s right!",
        "Expert_Human_Tutor": "Good job! 5 times 9 is indeed 45.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the result of 50 divided by 5? ||| student: 8 ||| teacher: Close, but not quite.",
        "Expert_Human_Tutor": "50 divided by 5 equals 10, not 8.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: How much is 4 times 12? ||| student: 46 ||| teacher: Almost.",
        "Expert_Human_Tutor": "4 times 12 is actually 48.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the square root of 64? ||| student: 6 ||| teacher: Close!",
        "Expert_Human_Tutor": "The square root of 64 is actually 8.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the sum of 40 and 15? ||| student: 54 ||| teacher: Almost.",
        "Expert_Human_Tutor": "40 plus 15 is 55, not 54.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 2 raised to the power of 5? ||| student: 8 ||| teacher: Close!",
        "Expert_Human_Tutor": "2 to the power of 5 is 32, not 8.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is 12 divided by 3? ||| student: 5 ||| teacher: Almost.",
        "Expert_Human_Tutor": "12 divided by 3 equals 4, not 5.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: Can you simplify 20/30? ||| student: 1/2 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "20/30 simplifies to 2/3, not 1/2.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 5 squared? ||| student: 20 ||| teacher: Close!",
        "Expert_Human_Tutor": "5 squared is 25, not 20.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the product of 4 and 7? ||| student: 30 ||| teacher: Almost.",
        "Expert_Human_Tutor": "4 times 7 is 28, not 30.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: How much is 6 plus 9? ||| student: 14 ||| teacher: Close, but incorrect.",
        "Expert_Human_Tutor": "6 plus 9 equals 15, not 14.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 2 times 6? ||| student: 10 ||| teacher: Close!",
        "Expert_Human_Tutor": "2 times 6 is actually 12, not 10.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is 15 minus 8? ||| student: 6 ||| teacher: Not quite.",
        "Expert_Human_Tutor": "15 minus 8 is 7, not 6.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: How much is 8 times 7? ||| student: 50 ||| teacher: Almost.",
        "Expert_Human_Tutor": "8 times 7 is 56, not 50.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the product of 3 and 12? ||| student: 38 ||| teacher: Close, but not quite.",
        "Expert_Human_Tutor": "3 times 12 is actually 36.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: How much is 100 divided by 20? ||| student: 4 ||| teacher: That’s correct!",
        "Expert_Human_Tutor": "Good job! 100 divided by 20 is indeed 5.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the sum of 55 and 18? ||| student: 73 ||| teacher: Close!",
        "Expert_Human_Tutor": "55 plus 18 equals 73.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 3 times 15? ||| student: 40 ||| teacher: Almost correct.",
        "Expert_Human_Tutor": "3 times 15 is actually 45, not 40.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is 8 squared? ||| student: 56 ||| teacher: Almost.",
        "Expert_Human_Tutor": "8 squared is 64, not 56.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 12 minus 4? ||| student: 9 ||| teacher: Not exactly.",
        "Expert_Human_Tutor": "12 minus 4 is 8.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the result of 15 divided by 3? ||| student: 6 ||| teacher: Close!",
        "Expert_Human_Tutor": "15 divided by 3 is actually 5, not 6.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 10% of 200? ||| student: 25 ||| teacher: Close!",
        "Expert_Human_Tutor": "10% of 200 is actually 20.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the square root of 81? ||| student: 7 ||| teacher: Almost correct.",
        "Expert_Human_Tutor": "The square root of 81 is 9, not 7.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 20% of 60? ||| student: 18 ||| teacher: Close!",
        "Expert_Human_Tutor": "20% of 60 is actually 12, not 18.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: How much is 3 plus 5? ||| student: 9 ||| teacher: Almost there!",
        "Expert_Human_Tutor": "3 plus 5 equals 8, not 9.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s 30 divided by 5? ||| student: 7 ||| teacher: Close!",
        "Expert_Human_Tutor": "30 divided by 5 is 6, not 7.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What’s the result of 7 times 5? ||| student: 25 ||| teacher: Almost.",
        "Expert_Human_Tutor": "7 times 5 is actually 35, not 25.",
        "Peda_Strategies": "provide_correction"
    },
    {
        "History": "||| teacher: What is 4 cubed? ||| student: 16 ||| teacher: Close!",
        "Expert_Human_Tutor": "4 cubed is actually 64, not 16.",
        "Peda_Strategies": "provide_correction"
    }
]

# Convert new entries into a DataFrame
new_df_provide_correction_36 = pd.DataFrame(new_entries_provide_correction_36)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_provide_correction_36], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("36 new 'provide_correction' entries added successfully!")
# Out:
# 36 new 'provide_correction' entries added successfully!

# %%
import pandas as pd

# Path to your existing CSV file
file_path = '/content/shuffled_reduced_dataset (GPT-4o).csv'  # Update with the correct file path

# Load the existing dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# New entries for the "provide_correction" strategy (35 new examples)
new_entries_provide_correction_35 = [
    {"History": "||| teacher: What’s 5 times 8? ||| student: 45 ||| teacher: Not quite.", "Expert_Human_Tutor": "Actually, 5 times 8 is 40, not 45.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s the sum of 30 and 25? ||| student: 54 ||| teacher: Close, but not quite.", "Expert_Human_Tutor": "30 plus 25 is 55, not 54.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: How much is 6 cubed? ||| student: 36 ||| teacher: Not exactly.", "Expert_Human_Tutor": "6 cubed is 216, not 36.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s 20% of 80? ||| student: 25 ||| teacher: Almost there.", "Expert_Human_Tutor": "20% of 80 is actually 16.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What is 7 times 7? ||| student: 48 ||| teacher: Close!", "Expert_Human_Tutor": "7 times 7 is 49, not 48.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s the result of 56 divided by 8? ||| student: 9 ||| teacher: Almost.", "Expert_Human_Tutor": "56 divided by 8 equals 7, not 9.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: How much is 4 plus 9? ||| student: 12 ||| teacher: Close, but not correct.", "Expert_Human_Tutor": "4 plus 9 is 13, not 12.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s the square of 9? ||| student: 81 ||| teacher: That’s correct!", "Expert_Human_Tutor": "Well done! 9 squared is indeed 81.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s 15 minus 6? ||| student: 8 ||| teacher: Not quite.", "Expert_Human_Tutor": "15 minus 6 is 9, not 8.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: How much is 7 times 9? ||| student: 72 ||| teacher: Almost correct.", "Expert_Human_Tutor": "7 times 9 is actually 63, not 72.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s 50% of 60? ||| student: 40 ||| teacher: Not quite.", "Expert_Human_Tutor": "50% of 60 is 30, not 40.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s the sum of 24 and 19? ||| student: 42 ||| teacher: Close.", "Expert_Human_Tutor": "24 plus 19 equals 43, not 42.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s 6 times 4? ||| student: 28 ||| teacher: Almost.", "Expert_Human_Tutor": "6 times 4 is actually 24, not 28.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: How much is 15 divided by 3? ||| student: 6 ||| teacher: Close, but incorrect.", "Expert_Human_Tutor": "15 divided by 3 is 5, not 6.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What is 3 squared? ||| student: 8 ||| teacher: Almost there!", "Expert_Human_Tutor": "3 squared is 9, not 8.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s 12 plus 15? ||| student: 26 ||| teacher: Not quite.", "Expert_Human_Tutor": "12 plus 15 is 27, not 26.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: How much is 40 minus 17? ||| student: 24 ||| teacher: Close, but incorrect.", "Expert_Human_Tutor": "40 minus 17 is actually 23.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s 100 divided by 25? ||| student: 2 ||| teacher: Not quite right.", "Expert_Human_Tutor": "100 divided by 25 is 4, not 2.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What is the result of 9 times 5? ||| student: 44 ||| teacher: Almost correct.", "Expert_Human_Tutor": "9 times 5 is actually 45, not 44.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s the square root of 49? ||| student: 8 ||| teacher: Close!", "Expert_Human_Tutor": "The square root of 49 is actually 7.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: How much is 7 plus 8? ||| student: 14 ||| teacher: Almost.", "Expert_Human_Tutor": "7 plus 8 equals 15, not 14.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s the product of 6 and 3? ||| student: 20 ||| teacher: Not quite.", "Expert_Human_Tutor": "6 times 3 is 18, not 20.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s 5 cubed? ||| student: 100 ||| teacher: Close, but incorrect.", "Expert_Human_Tutor": "5 cubed is 125, not 100.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: How much is 11 times 3? ||| student: 35 ||| teacher: Almost.", "Expert_Human_Tutor": "11 times 3 is actually 33.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s 60 divided by 4? ||| student: 12 ||| teacher: That’s right!", "Expert_Human_Tutor": "Good job! 60 divided by 4 is indeed 15.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: How much is 5 times 6? ||| student: 35 ||| teacher: Almost there.", "Expert_Human_Tutor": "5 times 6 is 30, not 35.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s the square of 10? ||| student: 100 ||| teacher: Correct!", "Expert_Human_Tutor": "That’s right! 10 squared is indeed 100.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s 8 times 6? ||| student: 42 ||| teacher: Close!", "Expert_Human_Tutor": "8 times 6 equals 48, not 42.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: How much is 9 plus 6? ||| student: 16 ||| teacher: Not quite.", "Expert_Human_Tutor": "9 plus 6 is 15, not 16.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s the result of 30 divided by 6? ||| student: 4 ||| teacher: Almost.", "Expert_Human_Tutor": "30 divided by 6 is actually 5.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s the product of 7 and 8? ||| student: 55 ||| teacher: Close, but incorrect.", "Expert_Human_Tutor": "7 times 8 is 56, not 55.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s 1/2 of 30? ||| student: 20 ||| teacher: Close, but incorrect.", "Expert_Human_Tutor": "Half of 30 is actually 15.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What is the result of 5 + 9? ||| student: 14 ||| teacher: Exactly right!", "Expert_Human_Tutor": "Nice work! 5 plus 9 equals 14.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s 14 minus 5? ||| student: 8 ||| teacher: Not quite.", "Expert_Human_Tutor": "14 minus 5 is actually 9.", "Peda_Strategies": "provide_correction"},
    {"History": "||| teacher: What’s 18 plus 7? ||| student: 26 ||| teacher: Close, but incorrect.", "Expert_Human_Tutor": "18 plus 7 is 25, not 26.", "Peda_Strategies": "provide_correction"}
]

# Convert new entries into a DataFrame
new_df_provide_correction_35 = pd.DataFrame(new_entries_provide_correction_35)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_provide_correction_35], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("35 new 'provide_correction' entries added successfully!")
# Out:
# 35 new 'provide_correction' entries added successfully!

# %%
import pandas as pd

# Path to your existing CSV file
file_path = '/content/shuffled_reduced_dataset (GPT-4o).csv'  # Update with the correct file path

# Load the existing dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# New entries for the "provide_similar_problem" strategy (35 new examples)
new_entries_provide_similar_problem_35 = [
    {"History": "||| teacher: How do you solve 3x = 12? ||| student: Divide by 3.", "Expert_Human_Tutor": "Good! Now try solving 4y = 20. It’s a similar idea.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s 7 + 8? ||| student: It’s 15.", "Expert_Human_Tutor": "Right! Now, what’s 6 + 9? It’s a similar addition problem.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How do I find 25% of 200? ||| student: Divide by 4.", "Expert_Human_Tutor": "Great! Now try finding 25% of 160 using the same strategy.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s the square of 6? ||| student: 36.", "Expert_Human_Tutor": "Correct! Now try finding the square of 7.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How do you solve for x in x + 5 = 10? ||| student: Subtract 5 from 10.", "Expert_Human_Tutor": "That’s right! Now try solving x + 4 = 9.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s the product of 4 and 8? ||| student: 32.", "Expert_Human_Tutor": "Good! Now, what’s the product of 5 and 7?", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How much is 50% of 120? ||| student: It’s 60.", "Expert_Human_Tutor": "Excellent! Now find 50% of 80 using the same approach.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s 12 - 5? ||| student: 7.", "Expert_Human_Tutor": "Correct! Now try 15 - 8; it’s a similar type of problem.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How do you simplify 10/20? ||| student: It’s 1/2.", "Expert_Human_Tutor": "Nicely done! Now simplify 15/30, which follows the same rule.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What is the result of 9 × 5? ||| student: It’s 45.", "Expert_Human_Tutor": "Good job! Now try calculating 8 × 6.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How much is 25% of 80? ||| student: 20.", "Expert_Human_Tutor": "Great! Now, can you find 25% of 60?", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s the answer to 30 divided by 5? ||| student: It’s 6.", "Expert_Human_Tutor": "Well done! Now try solving 25 divided by 5.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How do you find 10% of 200? ||| student: Divide by 10.", "Expert_Human_Tutor": "Excellent! Now find 10% of 150 using the same method.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s the product of 6 and 7? ||| student: 42.", "Expert_Human_Tutor": "Great! Now, what’s 5 times 8?", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How much is 8 + 9? ||| student: 17.", "Expert_Human_Tutor": "Correct! Now try adding 7 + 10.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How do you solve for y in 2y = 14? ||| student: Divide by 2.", "Expert_Human_Tutor": "Good job! Now try solving 3y = 18.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s 40% of 100? ||| student: 40.", "Expert_Human_Tutor": "Nicely done! Now find 40% of 50.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How much is 15 minus 7? ||| student: 8.", "Expert_Human_Tutor": "Correct! Now try 18 minus 9.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s the square of 5? ||| student: 25.", "Expert_Human_Tutor": "Right! Now, what’s the square of 8?", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How do you solve x - 3 = 7? ||| student: Add 3 to both sides.", "Expert_Human_Tutor": "Exactly! Now solve x - 2 = 6.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s the result of 3 times 12? ||| student: It’s 36.", "Expert_Human_Tutor": "Good job! Now, try 4 times 11.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How much is 75% of 100? ||| student: 75.", "Expert_Human_Tutor": "Perfect! Now find 75% of 200.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s 9 - 6? ||| student: 3.", "Expert_Human_Tutor": "Correct! Now try 12 - 7.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How do you simplify 12/18? ||| student: 2/3.", "Expert_Human_Tutor": "Great! Now simplify 8/12 using the same method.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s 10 times 4? ||| student: 40.", "Expert_Human_Tutor": "Good work! Now, try 9 times 5.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How much is 60 divided by 3? ||| student: 20.", "Expert_Human_Tutor": "Well done! Now try 45 divided by 3.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s the product of 7 and 6? ||| student: 42.", "Expert_Human_Tutor": "Great! Now, try calculating 8 times 5.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How much is 10% of 500? ||| student: 50.", "Expert_Human_Tutor": "Correct! Now try finding 10% of 250.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s 18 minus 9? ||| student: 9.", "Expert_Human_Tutor": "Exactly! Now try solving 14 minus 6.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How do you solve for z in 5z = 30? ||| student: Divide by 5.", "Expert_Human_Tutor": "Perfect! Now try solving 4z = 28.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s 15% of 100? ||| student: 15.", "Expert_Human_Tutor": "Correct! Now try finding 15% of 200.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How much is 6 plus 11? ||| student: 17.", "Expert_Human_Tutor": "That’s right! Now try adding 8 + 10.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s 5 cubed? ||| student: 125.", "Expert_Human_Tutor": "Correct! Now try calculating 4 cubed.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How do I simplify 14/21? ||| student: 2/3.", "Expert_Human_Tutor": "Nice job! Now simplify 10/15.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s 90 divided by 9? ||| student: 10.", "Expert_Human_Tutor": "Good work! Now try 80 divided by 8.", "Peda_Strategies": "provide_similar_problem"}
]

# Convert new entries into a DataFrame
new_df_provide_similar_problem_35 = pd.DataFrame(new_entries_provide_similar_problem_35)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_provide_similar_problem_35], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("35 new 'provide_similar_problem' entries added successfully!")
# Out:
# 35 new 'provide_similar_problem' entries added successfully!

# %%
import pandas as pd

# Path to your existing CSV file
file_path = '/content/shuffled_reduced_dataset (GPT-4o).csv'  # Update with the correct file path

# Load the existing dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# New entries for the "provide_similar_problem" strategy (35 new examples)
new_entries_provide_similar_problem_35 = [
    {"History": "||| teacher: How do you solve 2x = 18? ||| student: Divide by 2.", "Expert_Human_Tutor": "Good! Now try solving 3x = 21. It follows the same steps.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s the result of 6 + 8? ||| student: 14.", "Expert_Human_Tutor": "Great! Now try adding 7 + 9.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How do I find 50% of 120? ||| student: Divide by 2.", "Expert_Human_Tutor": "Correct! Now find 50% of 180 using the same strategy.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s the square of 4? ||| student: 16.", "Expert_Human_Tutor": "Good! Now try finding the square of 5.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How do you solve for x in x + 3 = 8? ||| student: Subtract 3.", "Expert_Human_Tutor": "Exactly! Now try solving x + 2 = 6.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s the product of 7 and 5? ||| student: 35.", "Expert_Human_Tutor": "Good! Now try finding the product of 6 and 5.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How much is 75% of 40? ||| student: 30.", "Expert_Human_Tutor": "Well done! Now, find 75% of 80.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s 14 - 6? ||| student: 8.", "Expert_Human_Tutor": "Correct! Now try calculating 15 - 7.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How do you simplify 8/16? ||| student: 1/2.", "Expert_Human_Tutor": "Exactly! Now simplify 10/20, which is similar.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s the answer to 4 × 6? ||| student: 24.", "Expert_Human_Tutor": "Great! Now, try calculating 5 × 6.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How much is 20% of 50? ||| student: 10.", "Expert_Human_Tutor": "Correct! Now find 20% of 80.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s the result of 45 divided by 5? ||| student: 9.", "Expert_Human_Tutor": "Well done! Now try solving 40 divided by 5.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How do you find 15% of 200? ||| student: Multiply by 0.15.", "Expert_Human_Tutor": "Great! Now try finding 15% of 300.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s the product of 4 and 9? ||| student: 36.", "Expert_Human_Tutor": "Good! Now try calculating 5 times 9.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How much is 7 + 10? ||| student: 17.", "Expert_Human_Tutor": "Right! Now try adding 6 + 11.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How do you solve for y in 3y = 15? ||| student: Divide by 3.", "Expert_Human_Tutor": "Exactly! Now try solving 2y = 12.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s 25% of 160? ||| student: 40.", "Expert_Human_Tutor": "Nice! Now find 25% of 120.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How much is 18 - 9? ||| student: 9.", "Expert_Human_Tutor": "Good job! Now try solving 17 - 8.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s the square of 9? ||| student: 81.", "Expert_Human_Tutor": "Great! Now try finding the square of 6.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How do you solve x - 5 = 7? ||| student: Add 5 to both sides.", "Expert_Human_Tutor": "Correct! Now solve x - 6 = 9.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s 8 times 3? ||| student: 24.", "Expert_Human_Tutor": "Good work! Now try calculating 7 times 4.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How much is 90% of 100? ||| student: 90.", "Expert_Human_Tutor": "Exactly! Now find 90% of 200.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s 11 - 4? ||| student: 7.", "Expert_Human_Tutor": "Right! Now try calculating 13 - 5.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How do you simplify 16/24? ||| student: 2/3.", "Expert_Human_Tutor": "Correct! Now try simplifying 18/27.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s 6 × 5? ||| student: 30.", "Expert_Human_Tutor": "Great! Now, try finding 7 × 5.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How much is 40 divided by 8? ||| student: 5.", "Expert_Human_Tutor": "Good job! Now try solving 32 divided by 8.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s the product of 3 and 7? ||| student: 21.", "Expert_Human_Tutor": "Well done! Now, try calculating 4 times 6.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How much is 25% of 200? ||| student: 50.", "Expert_Human_Tutor": "Right! Now try finding 25% of 300.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s 22 minus 11? ||| student: 11.", "Expert_Human_Tutor": "Correct! Now try 24 minus 12.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How do you solve for z in 6z = 42? ||| student: Divide by 6.", "Expert_Human_Tutor": "Good! Now try solving 5z = 35.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s 35% of 100? ||| student: 35.", "Expert_Human_Tutor": "Exactly! Now try finding 35% of 200.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How much is 9 plus 8? ||| student: 17.", "Expert_Human_Tutor": "Good! Now try calculating 10 + 7.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s 6 cubed? ||| student: 216.", "Expert_Human_Tutor": "Correct! Now try finding 5 cubed.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: How do you simplify 9/27? ||| student: 1/3.", "Expert_Human_Tutor": "Well done! Now simplify 12/36.", "Peda_Strategies": "provide_similar_problem"},
    {"History": "||| teacher: What’s 100 divided by 20? ||| student: 5.", "Expert_Human_Tutor": "Good work! Now try 80 divided by 20.", "Peda_Strategies": "provide_similar_problem"}
]

# Convert new entries into a DataFrame
new_df_provide_similar_problem_35 = pd.DataFrame(new_entries_provide_similar_problem_35)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_provide_similar_problem_35], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("35 new 'provide_similar_problem' entries added successfully!")
# Out:
# 35 new 'provide_similar_problem' entries added successfully!

# %%
import pandas as pd

# Path to your existing CSV file
file_path = '/content/shuffled_reduced_dataset (GPT-4o).csv'  # Update with the correct file path

# Load the existing dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# New entries for the "affirm_correct_answer" strategy (35 new examples)
new_entries_affirm_correct_answer_35 = [
    {"History": "||| teacher: What’s 9 times 3? ||| student: 27.", "Expert_Human_Tutor": "Yes, that’s exactly right! 9 times 3 is indeed 27.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s the sum of 14 and 6? ||| student: 20.", "Expert_Human_Tutor": "Correct! 14 plus 6 does equal 20.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 50% of 60? ||| student: 30.", "Expert_Human_Tutor": "Good job! 50% of 60 is indeed 30.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How do you solve 2x = 10? ||| student: x = 5.", "Expert_Human_Tutor": "Exactly! Dividing by 2 gives you x = 5.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 4 squared? ||| student: 16.", "Expert_Human_Tutor": "That’s correct! 4 squared is 16.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How much is 12 - 7? ||| student: 5.", "Expert_Human_Tutor": "Yes, that’s right! 12 minus 7 is 5.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 3 times 12? ||| student: 36.", "Expert_Human_Tutor": "Good answer! 3 times 12 is indeed 36.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 25% of 80? ||| student: 20.", "Expert_Human_Tutor": "Correct! 25% of 80 is 20.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How do you solve for y in y + 8 = 15? ||| student: y = 7.", "Expert_Human_Tutor": "That’s perfect! Solving for y gives you 7.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s the square root of 49? ||| student: 7.", "Expert_Human_Tutor": "Exactly right! The square root of 49 is 7.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s the result of 8 divided by 2? ||| student: 4.", "Expert_Human_Tutor": "Correct! 8 divided by 2 is 4.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 30% of 100? ||| student: 30.", "Expert_Human_Tutor": "Yes, that’s right! 30% of 100 is 30.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 5 plus 9? ||| student: 14.", "Expert_Human_Tutor": "Good job! 5 plus 9 is indeed 14.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How much is 7 times 7? ||| student: 49.", "Expert_Human_Tutor": "Correct! 7 times 7 is 49.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 20% of 50? ||| student: 10.", "Expert_Human_Tutor": "That’s right! 20% of 50 is 10.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How do you solve x - 4 = 6? ||| student: x = 10.", "Expert_Human_Tutor": "Yes, that’s correct! x equals 10.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s the cube of 3? ||| student: 27.", "Expert_Human_Tutor": "Good answer! 3 cubed is indeed 27.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How much is 9 plus 11? ||| student: 20.", "Expert_Human_Tutor": "Exactly! 9 plus 11 does equal 20.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s the result of 36 divided by 6? ||| student: 6.", "Expert_Human_Tutor": "Yes, that’s right! 36 divided by 6 is 6.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How do you find 10% of 200? ||| student: 20.", "Expert_Human_Tutor": "Perfect! 10% of 200 is 20.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s the square of 8? ||| student: 64.", "Expert_Human_Tutor": "Correct! 8 squared is 64.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 15 minus 5? ||| student: 10.", "Expert_Human_Tutor": "Exactly! 15 minus 5 equals 10.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How much is 7 times 6? ||| student: 42.", "Expert_Human_Tutor": "Good answer! 7 times 6 is indeed 42.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 20% of 150? ||| student: 30.", "Expert_Human_Tutor": "That’s correct! 20% of 150 is 30.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How do you solve for z in z + 6 = 15? ||| student: z = 9.", "Expert_Human_Tutor": "Exactly! Solving for z gives you 9.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s the product of 5 and 7? ||| student: 35.", "Expert_Human_Tutor": "Good job! 5 times 7 is 35.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How much is 12 + 13? ||| student: 25.", "Expert_Human_Tutor": "Correct! 12 plus 13 does equal 25.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 60 divided by 3? ||| student: 20.", "Expert_Human_Tutor": "Yes, that’s right! 60 divided by 3 is 20.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 2 to the power of 5? ||| student: 32.", "Expert_Human_Tutor": "Exactly! 2 raised to the power of 5 is 32.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How much is 45% of 200? ||| student: 90.", "Expert_Human_Tutor": "Correct! 45% of 200 is indeed 90.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s the sum of 18 and 7? ||| student: 25.", "Expert_Human_Tutor": "Good job! 18 plus 7 is indeed 25.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 9 divided by 3? ||| student: 3.", "Expert_Human_Tutor": "Right answer! 9 divided by 3 is 3.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How do you find 1/3 of 90? ||| student: 30.", "Expert_Human_Tutor": "Correct! 1/3 of 90 is 30.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 25 squared? ||| student: 625.", "Expert_Human_Tutor": "Absolutely correct! 25 squared is 625.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How much is 7 plus 10? ||| student: 17.", "Expert_Human_Tutor": "Exactly right! 7 plus 10 equals 17.", "Peda_Strategies": "affirm_correct_answer"}
]

# Convert new entries into a DataFrame
new_df_affirm_correct_answer_35 = pd.DataFrame(new_entries_affirm_correct_answer_35)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_affirm_correct_answer_35], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("35 new 'affirm_correct_answer' entries added successfully!")
# Out:
# 35 new 'affirm_correct_answer' entries added successfully!

# %%
import pandas as pd

# Path to your existing CSV file
file_path = '/content/shuffled_reduced_dataset (GPT-4o).csv'  # Update with the correct file path

# Load the existing dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# New entries for the "affirm_correct_answer" strategy (35 new examples)
new_entries_affirm_correct_answer_35 = [
    {"History": "||| teacher: What is 6 times 8? ||| student: 48.", "Expert_Human_Tutor": "Yes, that’s absolutely correct! 6 times 8 is 48.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How much is 15 plus 9? ||| student: 24.", "Expert_Human_Tutor": "Exactly! 15 plus 9 does equal 24.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 10% of 90? ||| student: 9.", "Expert_Human_Tutor": "Correct! 10% of 90 is indeed 9.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How do you solve for x in x - 7 = 5? ||| student: x = 12.", "Expert_Human_Tutor": "Exactly right! x is indeed 12.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s the cube of 4? ||| student: 64.", "Expert_Human_Tutor": "Yes, well done! 4 cubed is 64.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How much is 18 minus 10? ||| student: 8.", "Expert_Human_Tutor": "Correct! 18 minus 10 is indeed 8.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 7 times 5? ||| student: 35.", "Expert_Human_Tutor": "Good job! 7 times 5 is indeed 35.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 30% of 200? ||| student: 60.", "Expert_Human_Tutor": "Yes, that’s correct! 30% of 200 is 60.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How do you solve 4y = 16? ||| student: y = 4.", "Expert_Human_Tutor": "Exactly! y equals 4 in this case.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s the square of 7? ||| student: 49.", "Expert_Human_Tutor": "Right! The square of 7 is indeed 49.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 40 divided by 4? ||| student: 10.", "Expert_Human_Tutor": "Correct! 40 divided by 4 is 10.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How much is 5 plus 12? ||| student: 17.", "Expert_Human_Tutor": "Good answer! 5 plus 12 does equal 17.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 50% of 80? ||| student: 40.", "Expert_Human_Tutor": "Exactly! 50% of 80 is indeed 40.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 3 squared? ||| student: 9.", "Expert_Human_Tutor": "Correct! 3 squared is 9.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How much is 6 times 9? ||| student: 54.", "Expert_Human_Tutor": "That’s right! 6 times 9 is 54.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 25% of 100? ||| student: 25.", "Expert_Human_Tutor": "Perfect! 25% of 100 is indeed 25.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How do you solve x + 3 = 15? ||| student: x = 12.", "Expert_Human_Tutor": "Yes, you got it! x is 12.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s the product of 8 and 8? ||| student: 64.", "Expert_Human_Tutor": "Exactly right! 8 times 8 is 64.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s the sum of 23 and 12? ||| student: 35.", "Expert_Human_Tutor": "Correct! 23 plus 12 equals 35.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What is the square root of 81? ||| student: 9.", "Expert_Human_Tutor": "Yes, that’s correct! The square root of 81 is 9.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How much is 15 divided by 3? ||| student: 5.", "Expert_Human_Tutor": "That’s absolutely right! 15 divided by 3 is 5.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 6 plus 8? ||| student: 14.", "Expert_Human_Tutor": "Good job! 6 plus 8 is indeed 14.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How much is 5 times 10? ||| student: 50.", "Expert_Human_Tutor": "Yes, exactly! 5 times 10 is 50.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s the result of 20 divided by 4? ||| student: 5.", "Expert_Human_Tutor": "Correct! 20 divided by 4 is 5.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s the square of 5? ||| student: 25.", "Expert_Human_Tutor": "Exactly! The square of 5 is 25.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 18 minus 3? ||| student: 15.", "Expert_Human_Tutor": "Yes, that’s right! 18 minus 3 equals 15.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How do you solve for z in z - 2 = 6? ||| student: z = 8.", "Expert_Human_Tutor": "Exactly! z equals 8.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 5 cubed? ||| student: 125.", "Expert_Human_Tutor": "Correct! 5 cubed is indeed 125.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How much is 11 + 14? ||| student: 25.", "Expert_Human_Tutor": "Right! 11 plus 14 is 25.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 20% of 250? ||| student: 50.", "Expert_Human_Tutor": "That’s correct! 20% of 250 is 50.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 4 times 4? ||| student: 16.", "Expert_Human_Tutor": "Good answer! 4 times 4 is indeed 16.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How much is 7 plus 5? ||| student: 12.", "Expert_Human_Tutor": "Right! 7 plus 5 equals 12.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s 15 divided by 5? ||| student: 3.", "Expert_Human_Tutor": "Yes, that’s correct! 15 divided by 5 is 3.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: What’s the square root of 16? ||| student: 4.", "Expert_Human_Tutor": "Exactly! The square root of 16 is 4.", "Peda_Strategies": "affirm_correct_answer"},
    {"History": "||| teacher: How do you solve for y in y + 2 = 10? ||| student: y = 8.", "Expert_Human_Tutor": "That’s absolutely right! y is indeed 8.", "Peda_Strategies": "affirm_correct_answer"}
]

# Convert new entries into a DataFrame
new_df_affirm_correct_answer_35 = pd.DataFrame(new_entries_affirm_correct_answer_35)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_affirm_correct_answer_35], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("35 new 'affirm_correct_answer' entries added successfully!")
# Out:
# 35 new 'affirm_correct_answer' entries added successfully!

# %%
import pandas as pd

# Path to your existing CSV file
file_path = '/content/shuffled_reduced_dataset (GPT-4o).csv'  # Update with the correct file path

# Load the existing dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# New entries for the "provide_example" strategy (30 new examples)
new_entries_provide_example_30 = [
    {"History": "||| teacher: Can you explain how to add fractions? ||| student: I’m still confused.", "Expert_Human_Tutor": "Sure! For example, if you add 1/4 and 1/4, you get 2/4, which simplifies to 1/2.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I calculate the area of a rectangle? ||| student: I don’t remember the formula.", "Expert_Human_Tutor": "No problem! For example, if a rectangle has a length of 5 and a width of 3, the area is 5 × 3 = 15.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s the best way to multiply fractions? ||| student: I get confused with the steps.", "Expert_Human_Tutor": "I can help! For example, to multiply 1/2 by 3/4, you multiply the numerators (1 × 3 = 3) and the denominators (2 × 4 = 8), so the answer is 3/8.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What does it mean to find 10% of a number? ||| student: Not really.", "Expert_Human_Tutor": "Here’s an example: 10% of 50 is 5 because you move the decimal one place to the left or multiply 50 by 0.1.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do you divide decimals? ||| student: I’m a bit lost on that.", "Expert_Human_Tutor": "Sure, let’s take 4.5 ÷ 1.5 as an example. You move the decimal over, so it becomes 45 ÷ 15, which equals 3.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How can I calculate percentages? ||| student: I’m not sure.", "Expert_Human_Tutor": "Okay, let’s try finding 20% of 60. Multiply 60 by 0.2, and you get 12.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you give an example of squaring a number? ||| student: I’m still not clear.", "Expert_Human_Tutor": "Of course! For example, if you square 5, it’s 5 × 5, which equals 25.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I find the perimeter of a square? ||| student: I forgot.", "Expert_Human_Tutor": "If each side of a square is 4, the perimeter is 4 + 4 + 4 + 4, or 4 × 4 = 16.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of adding negative numbers? ||| student: I don’t understand.", "Expert_Human_Tutor": "Here’s one: -3 + (-2) equals -5, because adding two negative numbers keeps it negative.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you show me how to calculate the average? ||| student: Yes, please!", "Expert_Human_Tutor": "Sure! For example, the average of 4, 8, and 12 is (4 + 8 + 12) ÷ 3 = 8.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do you calculate the volume of a cube? ||| student: I’m not sure.", "Expert_Human_Tutor": "Let’s say each side of the cube is 3. The volume would be 3 × 3 × 3 = 27.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What does it mean to take half of a fraction? ||| student: Not really.", "Expert_Human_Tutor": "Okay, for example, half of 1/2 is 1/4, because 1/2 ÷ 2 = 1/4.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do you find the hypotenuse in a right triangle? ||| student: I’m confused.", "Expert_Human_Tutor": "Sure! For a triangle with sides of 3 and 4, the hypotenuse is √(3² + 4²) = √25 = 5.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of rounding numbers? ||| student: I don’t get it.", "Expert_Human_Tutor": "If you have 47 and want to round to the nearest ten, it rounds up to 50.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How can I calculate the probability of an event? ||| student: Not really sure.", "Expert_Human_Tutor": "For example, if you flip a coin, the probability of heads is 1 out of 2, or 50%.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I solve 3x = 15? ||| student: I forgot the steps.", "Expert_Human_Tutor": "Sure! For example, 3x = 15 means dividing by 3, so x = 5.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I multiply a whole number by a fraction? ||| student: I’m unsure.", "Expert_Human_Tutor": "If you multiply 4 by 1/2, you get 4 × 1/2 = 2.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of a prime number? ||| student: I don’t remember.", "Expert_Human_Tutor": "Here’s an example: 7 is a prime number because its only factors are 1 and 7.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you give an example of finding a percentage? ||| student: Please.", "Expert_Human_Tutor": "For example, 30% of 100 is 30 because 100 × 0.3 = 30.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do you add decimals? ||| student: Not quite sure.", "Expert_Human_Tutor": "Let’s add 2.5 and 3.1. You align the decimals, and 2.5 + 3.1 = 5.6.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of finding the mode? ||| student: I don’t remember.", "Expert_Human_Tutor": "Sure! In the set {1, 2, 2, 3}, the mode is 2 because it appears most often.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you show me an example of dividing by fractions? ||| student: I’m a little confused.", "Expert_Human_Tutor": "If you divide 1 by 1/2, it’s like multiplying by 2, so the answer is 2.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do you calculate the circumference? ||| student: I forgot.", "Expert_Human_Tutor": "For a circle with a diameter of 6, the circumference is π × 6 = 18.84.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of a mixed number? ||| student: No, can you show me?", "Expert_Human_Tutor": "Of course! 1 and 1/2 is a mixed number because it has both a whole number and a fraction.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I multiply two-digit numbers? ||| student: I don’t remember.", "Expert_Human_Tutor": "Let’s multiply 12 by 10. You get 120 because 12 × 10 = 120.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of dividing integers? ||| student: I don’t understand.", "Expert_Human_Tutor": "Sure! 20 divided by 5 is 4.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I calculate the average? ||| student: Please show me.", "Expert_Human_Tutor": "For the numbers 5, 10, and 15, the average is (5 + 10 + 15) ÷ 3 = 10.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you explain ratios? ||| student: I need help.", "Expert_Human_Tutor": "If there are 2 red marbles and 3 blue marbles, the ratio of red to blue is 2:3.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of simplifying fractions? ||| student: I don’t remember.", "Expert_Human_Tutor": "For example, 4/8 simplifies to 1/2 by dividing the top and bottom by 4.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I convert a decimal to a fraction? ||| student: I forgot.", "Expert_Human_Tutor": "For example, 0.5 can be written as 1/2.", "Peda_Strategies": "provide_example"}
]

# Convert new entries into a DataFrame
new_df_provide_example_30 = pd.DataFrame(new_entries_provide_example_30)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_provide_example_30], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("30 new 'provide_example' entries added successfully!")
# Out:
# 30 new 'provide_example' entries added successfully!

# %%
import pandas as pd

# Path to your existing CSV file
file_path = '/content/shuffled_reduced_dataset (GPT-4o).csv'  # Update with the correct file path

# Load the existing dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# New entries for the "provide_example" strategy (31 new examples)
new_entries_provide_example_31 = [
    {"History": "||| teacher: What’s an example of adding mixed numbers? ||| student: I’m not sure.", "Expert_Human_Tutor": "Sure! If you add 1 and 1/2 to 2 and 1/4, you get 3 and 3/4.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I find 75% of a number? ||| student: I don’t know.", "Expert_Human_Tutor": "For example, 75% of 80 is 60, because 80 × 0.75 = 60.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you give an example of finding the GCD? ||| student: I’m confused.", "Expert_Human_Tutor": "Sure! For the numbers 12 and 16, the greatest common divisor (GCD) is 4.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do you add negative numbers? ||| student: I’m unsure.", "Expert_Human_Tutor": "For example, -5 + (-3) equals -8, as adding negatives makes it more negative.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of multiplying decimals? ||| student: I don’t know.", "Expert_Human_Tutor": "If you multiply 0.5 by 0.2, the answer is 0.1.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I find the perimeter of a triangle? ||| student: I forgot.", "Expert_Human_Tutor": "If each side of the triangle is 3, the perimeter is 3 + 3 + 3 = 9.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you show me how to solve a two-step equation? ||| student: Yes, please.", "Expert_Human_Tutor": "Sure! For 2x + 3 = 11, first subtract 3, then divide by 2 to find x = 4.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of a unit rate? ||| student: I don’t understand.", "Expert_Human_Tutor": "If you drive 60 miles in 2 hours, your unit rate is 30 miles per hour.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I multiply by 100%? ||| student: I don’t know.", "Expert_Human_Tutor": "If you multiply 50 by 100%, it remains 50, as 100% is the whole amount.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of adding fractions with different denominators? ||| student: I’m unsure.", "Expert_Human_Tutor": "If you add 1/2 and 1/3, find a common denominator to get 3/6 + 2/6 = 5/6.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do you find the mode in a set? ||| student: I forgot.", "Expert_Human_Tutor": "For example, in {4, 5, 5, 6, 6, 6}, the mode is 6 because it appears the most.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you give an example of converting a fraction to a decimal? ||| student: I don’t remember.", "Expert_Human_Tutor": "Sure! 1/4 can be written as 0.25 by dividing 1 by 4.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of a proportion? ||| student: I don’t understand.", "Expert_Human_Tutor": "If 2 pencils cost $1, then 4 pencils would cost $2, maintaining the same proportion.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do you subtract mixed numbers? ||| student: I need help.", "Expert_Human_Tutor": "If you subtract 3 and 1/2 from 5 and 1/4, you get 1 and 3/4.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you explain a simple probability example? ||| student: I’m not sure.", "Expert_Human_Tutor": "If you roll a six-sided die, the probability of rolling a 3 is 1/6.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of multiplying integers? ||| student: Please explain.", "Expert_Human_Tutor": "For example, 4 times -3 equals -12, since one number is negative.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I simplify 12/36? ||| student: I’m lost.", "Expert_Human_Tutor": "To simplify, divide the numerator and denominator by 12, so 12/36 becomes 1/3.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you give an example of a right triangle? ||| student: I don’t understand.", "Expert_Human_Tutor": "Sure! A triangle with sides of 3, 4, and 5 is a right triangle.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of dividing decimals? ||| student: I don’t know how.", "Expert_Human_Tutor": "If you divide 0.6 by 0.2, you get 3, as 0.2 fits into 0.6 three times.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do you convert 75% to a decimal? ||| student: I forgot.", "Expert_Human_Tutor": "To convert, divide by 100. So, 75% becomes 0.75.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you show me an example of a linear equation? ||| student: I’m not sure.", "Expert_Human_Tutor": "Sure! The equation y = 2x + 1 is linear because it forms a straight line.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do you calculate the mean? ||| student: I don’t remember.", "Expert_Human_Tutor": "For example, the mean of 4, 6, and 8 is (4 + 6 + 8) ÷ 3 = 6.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of converting a decimal to a percentage? ||| student: I don’t understand.", "Expert_Human_Tutor": "Sure! If you have 0.25, multiply by 100 to get 25%.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you explain how to solve 3x = 9? ||| student: I forgot.", "Expert_Human_Tutor": "If 3x = 9, divide by 3 to get x = 3.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of finding the median? ||| student: I don’t know.", "Expert_Human_Tutor": "In the set {3, 7, 9}, the median is 7, as it’s the middle number.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I convert a fraction like 1/5 to a percentage? ||| student: I’m not sure.", "Expert_Human_Tutor": "To convert 1/5 to a percentage, multiply by 100 to get 20%.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you give an example of a mixed fraction? ||| student: I’m confused.", "Expert_Human_Tutor": "Certainly! 2 and 3/4 is a mixed fraction because it combines a whole and a fraction.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do you add decimals like 1.2 and 2.3? ||| student: I don’t know.", "Expert_Human_Tutor": "For 1.2 + 2.3, align the decimals and add, which equals 3.5.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of finding the least common multiple? ||| student: I need help.", "Expert_Human_Tutor": "For 4 and 6, the least common multiple (LCM) is 12.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do you solve x + 7 = 13? ||| student: I don’t remember.", "Expert_Human_Tutor": "Subtract 7 from both sides to find x = 6.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of finding the reciprocal? ||| student: I forgot.", "Expert_Human_Tutor": "For 2, the reciprocal is 1/2 because you flip it.", "Peda_Strategies": "provide_example"}
]

# Convert new entries into a DataFrame
new_df_provide_example_31 = pd.DataFrame(new_entries_provide_example_31)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_provide_example_31], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("31 new 'provide_example' entries added successfully!")
# Out:
# 31 new 'provide_example' entries added successfully!

# %%
import pandas as pd

# Path to your existing CSV file
file_path = '/content/shuffled_reduced_dataset (GPT-4o).csv'  # Update with the correct file path

# Load the existing dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# New entries for the "provide_example" strategy (30 new examples)
new_entries_provide_example_30 = [
    {"History": "||| teacher: Can you show me how to multiply fractions? ||| student: I’m still not sure.", "Expert_Human_Tutor": "Of course! For example, to multiply 1/3 by 2/5, multiply the numerators (1 × 2 = 2) and the denominators (3 × 5 = 15), so the answer is 2/15.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of calculating the area of a triangle? ||| student: I don’t remember.", "Expert_Human_Tutor": "Sure! For a triangle with a base of 5 and height of 4, the area is 1/2 × 5 × 4 = 10.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I convert a percentage to a decimal? ||| student: I don’t know.", "Expert_Human_Tutor": "For example, to convert 75% to a decimal, divide by 100, which gives you 0.75.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of subtracting negative numbers? ||| student: I’m confused.", "Expert_Human_Tutor": "If you have -6 - (-4), it’s like adding 4 to -6, so the result is -2.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How can I find the median of a data set? ||| student: I forgot the steps.", "Expert_Human_Tutor": "If you have {3, 6, 9}, the median is the middle number, which is 6.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of converting a fraction to a decimal? ||| student: Please show me.", "Expert_Human_Tutor": "Of course! 3/4 can be written as 0.75 by dividing 3 by 4.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I calculate the circumference of a circle? ||| student: I don’t know.", "Expert_Human_Tutor": "If a circle has a diameter of 10, the circumference is π × 10 = 31.4.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of adding mixed numbers? ||| student: I don’t get it.", "Expert_Human_Tutor": "If you add 2 and 1/2 to 3 and 1/4, you get 5 and 3/4.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you give an example of solving for x? ||| student: I’m still unsure.", "Expert_Human_Tutor": "For the equation 4x = 16, divide both sides by 4, so x = 4.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of finding the mode? ||| student: I forgot.", "Expert_Human_Tutor": "In the set {2, 4, 4, 5, 7}, the mode is 4 because it appears most frequently.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I convert a decimal like 0.6 to a fraction? ||| student: I don’t remember.", "Expert_Human_Tutor": "For 0.6, write it as 6/10, which simplifies to 3/5.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of calculating the volume of a cylinder? ||| student: I’m not sure.", "Expert_Human_Tutor": "If a cylinder has a radius of 3 and height of 5, the volume is π × 3² × 5 = 141.3.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do you find the least common multiple? ||| student: I don’t know.", "Expert_Human_Tutor": "For the numbers 5 and 6, the least common multiple (LCM) is 30.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you show me an example of a unit rate? ||| student: I’m confused.", "Expert_Human_Tutor": "Sure! If 12 apples cost $6, then the unit rate is $0.50 per apple.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of converting a fraction like 3/8 to a percentage? ||| student: I’m unsure.", "Expert_Human_Tutor": "To convert 3/8 to a percentage, multiply by 100 to get 37.5%.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I solve 2x - 4 = 10? ||| student: I don’t remember.", "Expert_Human_Tutor": "First, add 4 to both sides to get 2x = 14, then divide by 2, so x = 7.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you give an example of an improper fraction? ||| student: I’m not sure.", "Expert_Human_Tutor": "Sure! 7/3 is an improper fraction because the numerator is larger than the denominator.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do you find the mean of a set of numbers? ||| student: I don’t remember.", "Expert_Human_Tutor": "For {2, 4, 6}, add them up to get 12, then divide by 3 to get a mean of 4.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of finding the reciprocal? ||| student: I don’t get it.", "Expert_Human_Tutor": "The reciprocal of 3 is 1/3. You just flip the number.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How can I solve 5x = 25? ||| student: I need a reminder.", "Expert_Human_Tutor": "Simply divide both sides by 5, so x = 5.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of a prime number? ||| student: I don’t remember.", "Expert_Human_Tutor": "For example, 11 is a prime number because it has only two factors: 1 and 11.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I convert 0.75 to a fraction? ||| student: I forgot.", "Expert_Human_Tutor": "To convert, write it as 75/100, then simplify to 3/4.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of a mixed number? ||| student: I don’t remember.", "Expert_Human_Tutor": "Sure! 2 and 1/3 is a mixed number because it combines a whole number and a fraction.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you show me how to add decimals? ||| student: I’m still confused.", "Expert_Human_Tutor": "If you add 1.3 and 2.4, align the decimals, then add to get 3.7.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of calculating percentage increase? ||| student: I need help.", "Expert_Human_Tutor": "If something goes from 50 to 60, the increase is 10. Divide by the original amount (50) and multiply by 100 to get a 20% increase.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do you find 1/3 of a number? ||| student: I don’t know.", "Expert_Human_Tutor": "For example, 1/3 of 9 is 3 because 9 ÷ 3 = 3.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of subtracting decimals? ||| student: I’m a bit lost.", "Expert_Human_Tutor": "If you subtract 5.5 from 7.0, you get 1.5.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do you multiply mixed numbers? ||| student: I don’t know.", "Expert_Human_Tutor": "Convert 2 and 1/2 to an improper fraction (5/2) and multiply by another fraction.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you show me how to divide by a fraction? ||| student: I’m still unsure.", "Expert_Human_Tutor": "If you divide 1 by 1/4, it’s the same as multiplying by 4, so the answer is 4.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of a rational number? ||| student: I don’t remember.", "Expert_Human_Tutor": "Any number that can be written as a fraction, like 1/2 or 3, is a rational number.", "Peda_Strategies": "provide_example"}
]

# Convert new entries into a DataFrame
new_df_provide_example_30 = pd.DataFrame(new_entries_provide_example_30)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_provide_example_30], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("30 new 'provide_example' entries added successfully!")
# Out:
# 30 new 'provide_example' entries added successfully!

# %%
import pandas as pd

# Path to your existing CSV file
file_path = '/content/shuffled_reduced_dataset (GPT-4o).csv'  # Update with the correct file path

# Load the existing dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# New entries for the "provide_example" strategy (20 new examples)
new_entries_provide_example_20 = [
    {"History": "||| teacher: What’s an example of finding the absolute value? ||| student: I’m not sure.", "Expert_Human_Tutor": "For example, the absolute value of -7 is 7 because it’s the distance from zero.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you give an example of a mixed fraction? ||| student: I don’t quite remember.", "Expert_Human_Tutor": "Certainly! 1 and 1/2 is a mixed fraction, combining a whole number and a fraction.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of subtracting fractions? ||| student: I need help with that.", "Expert_Human_Tutor": "If you subtract 5/6 from 7/6, you get 2/6, which simplifies to 1/3.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I simplify an improper fraction? ||| student: I’m not sure.", "Expert_Human_Tutor": "For example, 9/4 can be written as 2 and 1/4.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of converting a percentage to a decimal? ||| student: I forgot.", "Expert_Human_Tutor": "To convert 45%, divide by 100, so it becomes 0.45.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you show me how to calculate a discount? ||| student: I’m confused.", "Expert_Human_Tutor": "If an item is $50 and there’s a 20% discount, multiply 50 by 0.2 to get a $10 discount.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of a square root? ||| student: I don’t remember.", "Expert_Human_Tutor": "The square root of 36 is 6, because 6 times 6 equals 36.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do you calculate the probability of an event? ||| student: I’m not sure.", "Expert_Human_Tutor": "If you draw a card from a deck, the probability of drawing a heart is 13 out of 52, or 1/4.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of multiplying by a power of ten? ||| student: I don’t know.", "Expert_Human_Tutor": "If you multiply 5 by 10, it becomes 50. By 100, it becomes 500.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you give me an example of converting meters to centimeters? ||| student: I’m not sure.", "Expert_Human_Tutor": "Sure! To convert 3 meters to centimeters, multiply by 100 to get 300 cm.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I solve 2x + 5 = 15? ||| student: I’m not clear on that.", "Expert_Human_Tutor": "Subtract 5 from both sides to get 2x = 10, then divide by 2, so x = 5.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of a negative exponent? ||| student: I don’t remember.", "Expert_Human_Tutor": "For example, 2 to the power of -2 equals 1/4, or 0.25.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you show me an example of a terminating decimal? ||| student: I’m not sure.", "Expert_Human_Tutor": "Sure! 0.75 is a terminating decimal because it doesn’t go on forever.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of a repeating decimal? ||| student: I don’t know.", "Expert_Human_Tutor": "The decimal 0.333... is repeating because the 3s go on infinitely.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I find the volume of a rectangular prism? ||| student: I’m lost.", "Expert_Human_Tutor": "If the prism’s length is 4, width is 3, and height is 2, the volume is 4 × 3 × 2 = 24.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: Can you give an example of an irrational number? ||| student: I don’t remember.", "Expert_Human_Tutor": "The number π (pi) is irrational because it cannot be written as a simple fraction.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of finding a percentage increase? ||| student: I don’t understand.", "Expert_Human_Tutor": "If a price goes from $50 to $60, the increase is 10. Divide by the original (50) and multiply by 100 to get a 20% increase.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do I solve x + 4 = 12? ||| student: I’m not sure.", "Expert_Human_Tutor": "Subtract 4 from both sides to find x = 8.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: What’s an example of dividing by a decimal? ||| student: I don’t understand.", "Expert_Human_Tutor": "To divide 1 by 0.5, you get 2 because 0.5 fits into 1 two times.", "Peda_Strategies": "provide_example"},
    {"History": "||| teacher: How do you find the least common multiple of two numbers? ||| student: I’m confused.", "Expert_Human_Tutor": "For 8 and 12, the least common multiple is 24 because it’s the smallest number that both can divide into.", "Peda_Strategies": "provide_example"}
]

# Convert new entries into a DataFrame
new_df_provide_example_20 = pd.DataFrame(new_entries_provide_example_20)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_provide_example_20], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("20 new 'provide_example' entries added successfully!")
# Out:
# 20 new 'provide_example' entries added successfully!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load both datasets
data1 = pd.read_csv('/content/reduced_dataset.csv')  # Path to the first dataset
data2 = pd.read_csv('/content/shuffled_reduced_dataset (GPT-4o).csv')  # Path to the second dataset (update the path as needed)

# Count occurrences of each pedagogical strategy in both datasets
strategy_counts1 = data1['Peda_Strategies'].value_counts()
strategy_counts2 = data2['Peda_Strategies'].value_counts()

# Combine the counts into a DataFrame for easier plotting
comparison_df = pd.DataFrame({
    'Original Dataset': strategy_counts1,
    'Augmented (GPT-4o) Dataset': strategy_counts2
}).fillna(0)  # Fill any missing values with 0

# Plot the comparison as a bar chart
comparison_df.plot(kind='bar', figsize=(12, 7))
plt.title('Comparison of Pedagogical Strategy Counts in Two Datasets')
plt.xlabel('Pedagogical Strategy')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Save the comparison chart as an image file
plt.savefig('pedagogical_strategy_comparison.png', dpi=300, bbox_inches='tight')

# Display the chart
plt.show()

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('/content/Unique_Rows_from_New_Dataset.csv')  # Replace 'your_dataset.csv' with the path to your dataset

# Shuffle the rows
shuffled_data = data.sample(frac=1, random_state=42).reset_index(drop=True)

# Save the shuffled dataset to a new file
shuffled_data.to_csv('shuffled_dataset.csv', index=False)

print("Dataset rows have been shuffled and saved as 'shuffled_dataset.csv'")
# Out:
# Dataset rows have been shuffled and saved as 'shuffled_dataset.csv'

# %%
import pandas as pd

# Path to your existing CSV file
file_path = '/content/shuffled_Train_dataset_GPT4o.csv'  # Update with the correct file path

# Load the existing dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# New entries for the "ask_question" strategy (35 new examples)
new_entries_ask_question_35 = [
    {"History": "||| teacher: Can you explain the steps to solve 3x + 2 = 11? ||| student: I’m not sure.", "Expert_Human_Tutor": "What would be your first step if you wanted to isolate x in this equation?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: How would you calculate 25% of a number? ||| student: I’m not really sure.", "Expert_Human_Tutor": "What do you think you should do to find a percentage of a number?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Why is it important to know the area formula for a triangle? ||| student: I don’t know.", "Expert_Human_Tutor": "When might you need to find the area of a triangle in a real-world situation?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Can you tell me how you would start solving 4y = 20? ||| student: I’m not sure.", "Expert_Human_Tutor": "If we want y alone on one side, what operation should we use here?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Do you know what it means to take the absolute value? ||| student: Not really.", "Expert_Human_Tutor": "What would the absolute value of -7 be?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: How do you find the perimeter of a square? ||| student: I forgot.", "Expert_Human_Tutor": "What information do we need to calculate the perimeter of a square?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Do you know how to find the slope of a line? ||| student: No, I’m not sure.", "Expert_Human_Tutor": "What two points on a line would you use to calculate the slope?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Can you explain how to divide fractions? ||| student: I’m not certain.", "Expert_Human_Tutor": "What happens to a fraction when you divide it by another fraction?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: How would you describe a prime number? ||| student: I don’t remember.", "Expert_Human_Tutor": "What do you think makes a number prime?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Why is it useful to understand percentages? ||| student: I’m not sure.", "Expert_Human_Tutor": "Where might you use percentages in daily life?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: What steps would you take to find the volume of a cylinder? ||| student: I don’t know.", "Expert_Human_Tutor": "What formula could you use if you know the radius and height of a cylinder?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Can you tell me what a reciprocal is? ||| student: I don’t remember.", "Expert_Human_Tutor": "What do you think the reciprocal of 2/3 would be?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Do you know how to calculate 10% of any number? ||| student: I think so.", "Expert_Human_Tutor": "What is the quick way to find 10% of a number?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Can you explain how we calculate the area of a rectangle? ||| student: I think I need help.", "Expert_Human_Tutor": "What are the two dimensions we need to multiply to get the area of a rectangle?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: What is a good way to estimate 45% of 80? ||| student: I don’t know.", "Expert_Human_Tutor": "What steps could you take to approximate the value quickly?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: How would you solve for x in x - 7 = 13? ||| student: I’m not sure.", "Expert_Human_Tutor": "What operation would you use to isolate x here?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Can you explain the difference between median and mean? ||| student: I think I need help with that.", "Expert_Human_Tutor": "What do you think happens to the values in a data set when you calculate the mean versus the median?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Do you know what it means to square a number? ||| student: Not exactly.", "Expert_Human_Tutor": "What do you think happens when you multiply a number by itself?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Can you explain how we use exponents in math? ||| student: I don’t really understand.", "Expert_Human_Tutor": "What does it mean if we see a small number, like 3²?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: How do you determine if a number is even or odd? ||| student: I’m not sure.", "Expert_Human_Tutor": "What is a quick way to test whether a number is even or odd?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: What would you do to solve for z in 5z = 25? ||| student: I’m not sure.", "Expert_Human_Tutor": "If we want to isolate z, what operation should we use here?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Do you understand the concept of rounding? ||| student: Not really.", "Expert_Human_Tutor": "What would be your method if you needed to round 67 to the nearest ten?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: How do you find the greatest common divisor of two numbers? ||| student: I’m not sure.", "Expert_Human_Tutor": "What’s the first step in identifying the factors that two numbers share?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Can you explain what a mixed number is? ||| student: I don’t quite remember.", "Expert_Human_Tutor": "What might a mixed number include that a simple fraction does not?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Do you know how to write a decimal as a percentage? ||| student: I don’t think so.", "Expert_Human_Tutor": "What would you do to convert 0.75 to a percentage?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: How would you simplify an expression like 3(2x + 5)? ||| student: I’m not sure.", "Expert_Human_Tutor": "What’s the first step in distributing the 3 through the parentheses?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Can you tell me how to convert a decimal to a fraction? ||| student: I don’t remember.", "Expert_Human_Tutor": "If you have a decimal like 0.25, what steps would you take to turn it into a fraction?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Do you know the difference between the numerator and the denominator? ||| student: Not really.", "Expert_Human_Tutor": "Which part of a fraction do you think represents the total number of parts?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Can you explain what a factor is in mathematics? ||| student: I’m not sure.", "Expert_Human_Tutor": "What makes a number a factor of another number?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: How would you add two mixed numbers like 2 and 1/2 and 3 and 3/4? ||| student: I don’t remember.", "Expert_Human_Tutor": "What would you add first: the whole numbers or the fractions?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Do you know how to find the product of 5 and 8? ||| student: I think so.", "Expert_Human_Tutor": "What does it mean when we say we want the 'product' of two numbers?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: How would you approach finding the area of a circle? ||| student: I’m not sure.", "Expert_Human_Tutor": "What key measurement of the circle do we need to use in the formula?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Do you know how to find the range in a set of data? ||| student: Not really.", "Expert_Human_Tutor": "What operation would you use between the largest and smallest values?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Can you tell me what it means to divide by a fraction? ||| student: I think I need help.", "Expert_Human_Tutor": "What would you do with the fraction if you wanted to divide by it?", "Peda_Strategies": "ask_question"},
    {"History": "||| teacher: Do you know how to convert 1/4 to a decimal? ||| student: I think I need help with that.", "Expert_Human_Tutor": "What operation would you perform to change a fraction like 1/4 into a decimal?", "Peda_Strategies": "ask_question"}
]

# Convert new entries into a DataFrame
new_df_ask_question_35 = pd.DataFrame(new_entries_ask_question_35)

# Append new entries to the existing dataset
df = pd.concat([df, new_df_ask_question_35], ignore_index=True)

# Save the updated dataset back to CSV
df.to_csv(file_path, index=False)

print("35 new 'ask_question' entries added successfully!")
# Out:
# 35 new 'ask_question' entries added successfully!

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('/content/shuffled_Train_dataset_GPT4o.csv')  # Replace 'your_dataset.csv' with the path to your dataset

# Shuffle the rows
shuffled_data = data.sample(frac=1, random_state=42).reset_index(drop=True)

# Save the shuffled dataset to a new file
shuffled_data.to_csv('Normalized_shuffled_Train_dataset_GPT4o.csv', index=False)

print("Dataset rows have been shuffled and saved as 'shuffled_dataset.csv'")
# Out:
# Dataset rows have been shuffled and saved as 'shuffled_dataset.csv'
